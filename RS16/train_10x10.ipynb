# %% [markdown]
# # 基于强化学习的五子棋AI训练

# %% [markdown]
# * Content：采用强化学习（策略价值网络），训练五子棋AI；棋盘大小 10 * 10
# * Author:  HuiHui
# * Date:    2020-06-04
# * Reference:

# %% [markdown]
# ## 介绍

# %% [markdown]
# * **强化学习：**
#     &emsp;1. 强化学习四要素：状态(state)、动作(action)、策略（policy）、奖励(reward)
#     &emsp;2. RL考虑的是个体（Agent）与环境（Environment）的交互问题，目标是找到一个最优策略，使Agent获得尽可能多的来自环境的奖励
#     &emsp;3. 强化学习Agent：基于价值的强化学习、基于策略强化学习、结合策略梯度以及价值函数的强化学习
#
# * **实现思路：**
#     &emsp;下棋对弈场景是环境，每一种棋盘布局就是一个状态，所有可能的落子位置是动作空间，落子概率为策略，胜率就是奖励；采用策略价值网络训练AI,使用蒙特卡洛树搜索（MCTS）来进行策略优化,MCTS通过self－play来生成数据供深度神经网络学习,神经网络学习输入为当前棋盘，输出为双端口，分别表示当前棋盘的状态值（value）和当前棋盘各个位置的走子的概率
#
# * **项目文件结构：**
#     &emsp;1. game.py：定义了游戏的棋盘、获取棋盘状态、下棋、判断是否有人胜利、绘制人机对弈的可视化棋盘、自我对弈；
#     &emsp;2. human_play.py：人机对弈，在可视化界面下实现与AI的对弈；
#     &emsp;3. mcts_alphaZero.py：实现Alpha_Zero中的MCTS，使用策略网络来指导树搜索并计算叶节点；
#     &emsp;4. mcts_pure.py：实现随机走子策略的MCTS；
#     &emsp;5. policy_value_net_pytorch.py：策略价值网络，用来指导MCTS搜索并计算叶子节点；
#     &emsp;6. train_10x10.ipynb：训练AI主程序;
#     &emsp;7. best_policy.model：10X10棋盘下训练得到的AI最优策略模型；
#     &emsp;8. demo_10x10.ipynb：人机对弈demo.

# %% [markdown]
# ## 导入相关库

# %%
from __future__ import print_function
import random
import numpy as np
# deque 是一个双端队列
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure # 随机走子策略的AI
from mcts_alphaZero import MCTSPlayer # AlphaGo方式的AI
from policy_value_net_pytorch import PolicyValueNet  # Pytorch

# %% [markdown]
# ## AI训练主程序

# %%
class TrainPipeline():
    def __init__(self, init_model=None):
        # 设置棋盘和游戏的参数
        self.board_width = 10
        self.board_height = 10
        self.n_in_row = 4
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # 设置训练参数
        self.learn_rate = 2e-3 # 基准学习率
        self.lr_multiplier = 1.0  # 基于KL自动调整学习倍速
        self.temp = 1.0  # 温度参数
        self.n_playout = 400  # 每下一步棋，模拟的步骤数
        self.c_puct = 5 # exploitation和exploration之间的折中系数
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size) #使用 deque 创建一个双端队列
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02 # 早停检查
        self.check_freq = 50 # 每50次检查一次，策略价值网络是否更新
        self.game_batch_num = 500 # 训练多少个epoch
        self.best_win_ratio = 0.0 # 当前最佳胜率，用他来判断是否有更好的模型
        # 弱AI（纯MCTS）模拟步数，用于给训练的策略AI提供对手
        self.pure_mcts_playout_num = 1000
        if init_model:
            # 通过init_model设置策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height, model_file=init_model)
        else:
            # 训练一个新的策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height)
        # AI Player，设置is_selfplay=1 自我对弈，因为是在进行训练
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)
        
  # 通过旋转和翻转增加数据集, play_data: [(state, mcts_prob, winner_z), ..., ...]
    def get_equi_data(self, play_data):
        extend_data = []
        for state, mcts_porb, winner in play_data:
            # 在4个方向上进行expand，每个方向都进行旋转，水平翻转
            for i in [1, 2, 3, 4]:
                # 逆时针旋转
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
                # 水平翻转
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
        return extend_data

    # 收集自我对弈数据，用于训练
    def collect_selfplay_data(self, n_games=1):
        for i in range(n_games):
            # 与MCTS Player进行对弈
            winner, play_data = self.game.start_self_play(self.mcts_player, temp=self.temp)
            play_data = list(play_data)[:]
            # 保存下了多少步
            self.episode_len = len(play_data)
            # 增加数据 play_data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)
            
      # 更新策略网络
    def policy_update(self):
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        # 保存更新前的old_probs, old_v
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            # 每次训练，调整参数，返回loss和entropy
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            # 输入状态，得到行动的可能性和状态值，按照batch进行输入
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            # 计算更新前后两次的loss差
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # 动态调整学习倍率 lr_multiplier
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    # 用于评估训练网络的质量，评估一共10场play，返回比赛胜率（赢1分、输0分、平0.5分）
    def policy_evaluate(self, n_games=10):
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct, n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5, n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            # AI和弱AI（纯MCTS）对弈，不需要可视化 is_shown=0，双方轮流职黑 start_player=i % 2
            winner = self.game.start_play(current_mcts_player, pure_mcts_player, start_player=i % 2, is_shown=0)
            win_cnt[winner] += 1
        # 计算胜率，平手计为0.5分
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio
    
    def run(self):
        # 开始训练
        try:
            # 训练game_batch_num次，每个batch比赛play_batch_size场
            for i in range(self.game_batch_num):
                # 收集自我对弈数据
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # 判断当前模型的表现，保存最优模型
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    # 保存当前策略
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("发现新的最优策略，进行策略更新")
                        self.best_win_ratio = win_ratio
                        # 更新最优策略
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')


if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# /Users/wangdonghui/Desktop/ZGZ/RS/AI-Training-Course/RS16/policy_value_net_pytorch.py:45: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# /Users/wangdonghui/anaconda/lib/python3.6/site-packages/torch/nn/functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:22
# batch i:2, episode_len:33
# batch i:3, episode_len:17
# kl:0.02070,lr_multiplier:1.000,loss:5.559216499328613,entropy:4.589074611663818,explained_var_old:-0.001,explained_var_new:0.084
# batch i:4, episode_len:22
# kl:0.00769,lr_multiplier:1.500,loss:5.586826801300049,entropy:4.593297958374023,explained_var_old:-0.001,explained_var_new:0.006
# batch i:5, episode_len:14
# kl:0.00883,lr_multiplier:2.250,loss:5.5724921226501465,entropy:4.587553977966309,explained_var_old:-0.002,explained_var_new:0.031
# batch i:6, episode_len:24
# kl:0.01463,lr_multiplier:2.250,loss:5.482388496398926,entropy:4.586917877197266,explained_var_old:0.034,explained_var_new:0.139
# batch i:7, episode_len:19
# kl:0.05558,lr_multiplier:1.500,loss:5.329034328460693,entropy:4.532655239105225,explained_var_old:0.068,explained_var_new:0.246
# batch i:8, episode_len:13
# kl:0.00848,lr_multiplier:2.250,loss:5.277288913726807,entropy:4.496841907501221,explained_var_old:0.210,explained_var_new:0.281
# batch i:9, episode_len:23
# kl:0.01851,lr_multiplier:2.250,loss:5.371347427368164,entropy:4.459500789642334,explained_var_old:0.275,explained_var_new:0.356
# batch i:10, episode_len:15
# kl:0.01892,lr_multiplier:2.250,loss:5.190008640289307,entropy:4.5085554122924805,explained_var_old:0.290,explained_var_new:0.339
# batch i:11, episode_len:17
# kl:0.03854,lr_multiplier:2.250,loss:5.101501941680908,entropy:4.485236167907715,explained_var_old:0.287,explained_var_new:0.384
# batch i:12, episode_len:17
# kl:0.09110,lr_multiplier:1.500,loss:5.068123817443848,entropy:4.4795732498168945,explained_var_old:0.291,explained_var_new:0.405
# batch i:13, episode_len:18
# kl:0.17224,lr_multiplier:1.000,loss:5.1907572746276855,entropy:4.3449554443359375,explained_var_old:0.279,explained_var_new:0.334
# batch i:14, episode_len:11
# kl:0.09577,lr_multiplier:0.667,loss:5.059110164642334,entropy:4.475238800048828,explained_var_old:0.342,explained_var_new:0.378
# batch i:15, episode_len:9
# kl:0.02797,lr_multiplier:0.667,loss:4.991966724395752,entropy:4.4088134765625,explained_var_old:0.321,explained_var_new:0.416
# batch i:16, episode_len:26
# kl:0.01438,lr_multiplier:0.667,loss:5.167512893676758,entropy:4.412780284881592,explained_var_old:0.134,explained_var_new:0.224
# batch i:17, episode_len:11
# kl:0.02123,lr_multiplier:0.667,loss:5.091320991516113,entropy:4.394481658935547,explained_var_old:0.194,explained_var_new:0.273
# batch i:18, episode_len:21
# kl:0.01992,lr_multiplier:0.667,loss:4.965519428253174,entropy:4.3055009841918945,explained_var_old:0.307,explained_var_new:0.393
# batch i:19, episode_len:19
# kl:0.02508,lr_multiplier:0.667,loss:4.870542526245117,entropy:4.341369152069092,explained_var_old:0.328,explained_var_new:0.449
# batch i:20, episode_len:18
# kl:0.02407,lr_multiplier:0.667,loss:4.936945915222168,entropy:4.330618381500244,explained_var_old:0.328,explained_var_new:0.403
# batch i:21, episode_len:11
# kl:0.02275,lr_multiplier:0.667,loss:4.831874847412109,entropy:4.336127281188965,explained_var_old:0.405,explained_var_new:0.470
# batch i:22, episode_len:10
# kl:0.02123,lr_multiplier:0.667,loss:4.9223527908325195,entropy:4.30856990814209,explained_var_old:0.321,explained_var_new:0.381
# batch i:23, episode_len:13
# kl:0.01464,lr_multiplier:0.667,loss:4.897829532623291,entropy:4.301397800445557,explained_var_old:0.331,explained_var_new:0.403
# batch i:24, episode_len:27
# kl:0.01650,lr_multiplier:0.667,loss:4.858649253845215,entropy:4.331811428070068,explained_var_old:0.384,explained_var_new:0.453
# batch i:25, episode_len:25
# kl:0.01862,lr_multiplier:0.667,loss:4.797144889831543,entropy:4.2623701095581055,explained_var_old:0.414,explained_var_new:0.464
# batch i:26, episode_len:15
# kl:0.02088,lr_multiplier:0.667,loss:4.713082790374756,entropy:4.276180267333984,explained_var_old:0.497,explained_var_new:0.551
# batch i:27, episode_len:17
# kl:0.02450,lr_multiplier:0.667,loss:4.763791561126709,entropy:4.253384590148926,explained_var_old:0.416,explained_var_new:0.486
# batch i:28, episode_len:21
# kl:0.04642,lr_multiplier:0.444,loss:4.568453788757324,entropy:4.221499919891357,explained_var_old:0.509,explained_var_new:0.608
# batch i:29, episode_len:16
# kl:0.02820,lr_multiplier:0.444,loss:4.736715316772461,entropy:4.2069315910339355,explained_var_old:0.430,explained_var_new:0.460
# batch i:30, episode_len:19
# kl:0.03046,lr_multiplier:0.444,loss:4.585217475891113,entropy:4.152160167694092,explained_var_old:0.480,explained_var_new:0.524
# batch i:31, episode_len:16
# kl:0.02260,lr_multiplier:0.444,loss:4.6923723220825195,entropy:4.138708114624023,explained_var_old:0.394,explained_var_new:0.435
# batch i:32, episode_len:18
# kl:0.01341,lr_multiplier:0.444,loss:4.715030193328857,entropy:4.208189964294434,explained_var_old:0.409,explained_var_new:0.455
# batch i:33, episode_len:17
# kl:0.02360,lr_multiplier:0.444,loss:4.7205400466918945,entropy:4.073309421539307,explained_var_old:0.357,explained_var_new:0.400
# batch i:34, episode_len:18
# kl:0.03842,lr_multiplier:0.444,loss:4.777592182159424,entropy:4.162509441375732,explained_var_old:0.270,explained_var_new:0.344
# batch i:35, episode_len:16
# kl:0.03155,lr_multiplier:0.444,loss:4.788617134094238,entropy:4.122805595397949,explained_var_old:0.278,explained_var_new:0.352
# batch i:36, episode_len:21
# kl:0.02906,lr_multiplier:0.444,loss:4.847243309020996,entropy:4.136380195617676,explained_var_old:0.170,explained_var_new:0.281
# batch i:37, episode_len:24
# kl:0.02048,lr_multiplier:0.444,loss:4.759461402893066,entropy:4.08218240737915,explained_var_old:0.250,explained_var_new:0.328
# batch i:38, episode_len:23
# kl:0.01579,lr_multiplier:0.444,loss:4.6045684814453125,entropy:4.0618815422058105,explained_var_old:0.368,explained_var_new:0.447
# batch i:39, episode_len:21
# kl:0.01892,lr_multiplier:0.444,loss:4.679560661315918,entropy:4.058971881866455,explained_var_old:0.314,explained_var_new:0.380
# batch i:40, episode_len:11
# kl:0.01408,lr_multiplier:0.444,loss:4.723397254943848,entropy:4.068002223968506,explained_var_old:0.266,explained_var_new:0.339
# batch i:41, episode_len:11
# kl:0.01138,lr_multiplier:0.444,loss:4.590174674987793,entropy:4.05293083190918,explained_var_old:0.349,explained_var_new:0.413
# batch i:42, episode_len:9
# kl:0.01363,lr_multiplier:0.444,loss:4.672964096069336,entropy:4.058234214782715,explained_var_old:0.304,explained_var_new:0.371
# batch i:43, episode_len:23
# kl:0.01931,lr_multiplier:0.444,loss:4.584322929382324,entropy:4.014800548553467,explained_var_old:0.378,explained_var_new:0.434
# batch i:44, episode_len:15
# kl:0.01101,lr_multiplier:0.444,loss:4.627930164337158,entropy:4.042008399963379,explained_var_old:0.308,explained_var_new:0.385
# batch i:45, episode_len:19
# kl:0.01791,lr_multiplier:0.444,loss:4.540534973144531,entropy:3.961136817932129,explained_var_old:0.363,explained_var_new:0.442
# batch i:46, episode_len:21
# kl:0.02270,lr_multiplier:0.444,loss:4.5555419921875,entropy:3.995988130569458,explained_var_old:0.355,explained_var_new:0.418
# batch i:47, episode_len:11
# kl:0.01147,lr_multiplier:0.444,loss:4.491063117980957,entropy:3.980164051055908,explained_var_old:0.424,explained_var_new:0.492
# batch i:48, episode_len:21
# kl:0.01870,lr_multiplier:0.444,loss:4.522869110107422,entropy:3.934948205947876,explained_var_old:0.352,explained_var_new:0.425
# batch i:49, episode_len:21
# kl:0.01894,lr_multiplier:0.444,loss:4.397124290466309,entropy:3.9356513023376465,explained_var_old:0.466,explained_var_new:0.535
# batch i:50, episode_len:19
# kl:0.01499,lr_multiplier:0.444,loss:4.389654159545898,entropy:4.009494304656982,explained_var_old:0.531,explained_var_new:0.597
# current self-play batch: 50
# num_playouts:1000, win: 3, lose: 7, tie:0
# 发现新的最优策略，进行策略更新
# batch i:51, episode_len:10
# kl:0.03973,lr_multiplier:0.444,loss:4.379265785217285,entropy:3.868232488632202,explained_var_old:0.427,explained_var_new:0.496
# batch i:52, episode_len:11
# kl:0.03985,lr_multiplier:0.444,loss:4.337943077087402,entropy:3.967290163040161,explained_var_old:0.511,explained_var_new:0.591
# batch i:53, episode_len:28
# kl:0.02443,lr_multiplier:0.444,loss:4.43353271484375,entropy:3.9447360038757324,explained_var_old:0.436,explained_var_new:0.507
# batch i:54, episode_len:29
# kl:0.02513,lr_multiplier:0.444,loss:4.446000099182129,entropy:3.872208595275879,explained_var_old:0.373,explained_var_new:0.458
# batch i:55, episode_len:13
# kl:0.02070,lr_multiplier:0.444,loss:4.429287433624268,entropy:3.9447779655456543,explained_var_old:0.432,explained_var_new:0.493
# batch i:56, episode_len:16
# kl:0.02922,lr_multiplier:0.444,loss:4.428858280181885,entropy:3.8997788429260254,explained_var_old:0.361,explained_var_new:0.437
# batch i:57, episode_len:16
# kl:0.02962,lr_multiplier:0.444,loss:4.474386692047119,entropy:3.9629242420196533,explained_var_old:0.373,explained_var_new:0.452
# batch i:58, episode_len:21
# kl:0.02959,lr_multiplier:0.444,loss:4.357915878295898,entropy:3.7589383125305176,explained_var_old:0.417,explained_var_new:0.491
# batch i:59, episode_len:17
# kl:0.02514,lr_multiplier:0.444,loss:4.35282039642334,entropy:3.855694532394409,explained_var_old:0.396,explained_var_new:0.489
# batch i:60, episode_len:12
# kl:0.01918,lr_multiplier:0.444,loss:4.412149906158447,entropy:3.856865882873535,explained_var_old:0.386,explained_var_new:0.443
# batch i:61, episode_len:13
# kl:0.01557,lr_multiplier:0.444,loss:4.3667073249816895,entropy:3.8865857124328613,explained_var_old:0.402,explained_var_new:0.489
# batch i:62, episode_len:14
# kl:0.01187,lr_multiplier:0.444,loss:4.417881011962891,entropy:3.856966257095337,explained_var_old:0.378,explained_var_new:0.484
# batch i:63, episode_len:26
# kl:0.01482,lr_multiplier:0.444,loss:4.328812599182129,entropy:3.839264392852783,explained_var_old:0.390,explained_var_new:0.460
# batch i:64, episode_len:17
# kl:0.02007,lr_multiplier:0.444,loss:4.427059173583984,entropy:3.781141519546509,explained_var_old:0.296,explained_var_new:0.386
# batch i:65, episode_len:19
# kl:0.01938,lr_multiplier:0.444,loss:4.258690357208252,entropy:3.7701807022094727,explained_var_old:0.439,explained_var_new:0.513
# batch i:66, episode_len:14
# kl:0.02169,lr_multiplier:0.444,loss:4.3539838790893555,entropy:3.7791647911071777,explained_var_old:0.332,explained_var_new:0.416
# batch i:67, episode_len:24
# kl:0.01546,lr_multiplier:0.444,loss:4.306569576263428,entropy:3.794344425201416,explained_var_old:0.356,explained_var_new:0.456
# batch i:68, episode_len:17
# kl:0.02520,lr_multiplier:0.444,loss:4.26849365234375,entropy:3.6990585327148438,explained_var_old:0.388,explained_var_new:0.466
# batch i:69, episode_len:9
# kl:0.02649,lr_multiplier:0.444,loss:4.422723770141602,entropy:3.836935043334961,explained_var_old:0.298,explained_var_new:0.394
# batch i:70, episode_len:11
# kl:0.01772,lr_multiplier:0.444,loss:4.334741592407227,entropy:3.719942569732666,explained_var_old:0.340,explained_var_new:0.411
# batch i:71, episode_len:17
# kl:0.01450,lr_multiplier:0.444,loss:4.133026599884033,entropy:3.700230598449707,explained_var_old:0.492,explained_var_new:0.593
# batch i:72, episode_len:16
# kl:0.01951,lr_multiplier:0.444,loss:4.255302429199219,entropy:3.7384655475616455,explained_var_old:0.392,explained_var_new:0.483
# batch i:73, episode_len:13
# kl:0.01690,lr_multiplier:0.444,loss:4.295835494995117,entropy:3.7560348510742188,explained_var_old:0.361,explained_var_new:0.458
# batch i:74, episode_len:9
# kl:0.02171,lr_multiplier:0.444,loss:4.306907653808594,entropy:3.673248291015625,explained_var_old:0.271,explained_var_new:0.385
# batch i:75, episode_len:19
# kl:0.02239,lr_multiplier:0.444,loss:4.269155502319336,entropy:3.767627000808716,explained_var_old:0.334,explained_var_new:0.425
# batch i:76, episode_len:16
# kl:0.03178,lr_multiplier:0.444,loss:4.26688289642334,entropy:3.6271767616271973,explained_var_old:0.314,explained_var_new:0.427
# batch i:77, episode_len:18
# kl:0.03026,lr_multiplier:0.444,loss:4.144246578216553,entropy:3.5904383659362793,explained_var_old:0.372,explained_var_new:0.485
# batch i:78, episode_len:12
# kl:0.02493,lr_multiplier:0.444,loss:4.0949201583862305,entropy:3.572605848312378,explained_var_old:0.347,explained_var_new:0.454
# batch i:79, episode_len:11
# kl:0.01673,lr_multiplier:0.444,loss:4.222395420074463,entropy:3.695517063140869,explained_var_old:0.349,explained_var_new:0.441
# batch i:80, episode_len:17
# kl:0.01887,lr_multiplier:0.444,loss:4.155857086181641,entropy:3.5154013633728027,explained_var_old:0.334,explained_var_new:0.422
# batch i:81, episode_len:12
# kl:0.02076,lr_multiplier:0.444,loss:3.986558437347412,entropy:3.5808796882629395,explained_var_old:0.435,explained_var_new:0.520
# batch i:82, episode_len:7
# kl:0.02013,lr_multiplier:0.444,loss:4.013896465301514,entropy:3.501495122909546,explained_var_old:0.436,explained_var_new:0.526
# batch i:83, episode_len:7
# kl:0.01268,lr_multiplier:0.444,loss:4.160418510437012,entropy:3.596942901611328,explained_var_old:0.316,explained_var_new:0.412
# batch i:84, episode_len:7
# kl:0.02362,lr_multiplier:0.444,loss:4.016852378845215,entropy:3.455442428588867,explained_var_old:0.387,explained_var_new:0.480
# batch i:85, episode_len:15
# kl:0.02103,lr_multiplier:0.444,loss:3.979912757873535,entropy:3.445800304412842,explained_var_old:0.373,explained_var_new:0.460
# batch i:86, episode_len:14
# kl:0.02080,lr_multiplier:0.444,loss:4.056356430053711,entropy:3.557199239730835,explained_var_old:0.365,explained_var_new:0.452
# batch i:87, episode_len:11
# kl:0.03001,lr_multiplier:0.444,loss:4.0021138191223145,entropy:3.460442543029785,explained_var_old:0.430,explained_var_new:0.524
# batch i:88, episode_len:12
# kl:0.02084,lr_multiplier:0.444,loss:4.006519794464111,entropy:3.5440316200256348,explained_var_old:0.403,explained_var_new:0.487
# batch i:89, episode_len:26
# kl:0.01984,lr_multiplier:0.444,loss:4.006408214569092,entropy:3.512500762939453,explained_var_old:0.408,explained_var_new:0.493
# batch i:90, episode_len:15
# kl:0.02644,lr_multiplier:0.444,loss:3.9631588459014893,entropy:3.3740882873535156,explained_var_old:0.342,explained_var_new:0.464
# batch i:91, episode_len:13
# kl:0.01718,lr_multiplier:0.444,loss:4.056836128234863,entropy:3.460418224334717,explained_var_old:0.288,explained_var_new:0.376
# batch i:92, episode_len:9
# kl:0.02556,lr_multiplier:0.444,loss:3.9697368144989014,entropy:3.399082899093628,explained_var_old:0.396,explained_var_new:0.503
# batch i:93, episode_len:20
# kl:0.02280,lr_multiplier:0.444,loss:3.9727578163146973,entropy:3.479278087615967,explained_var_old:0.352,explained_var_new:0.444
# batch i:94, episode_len:16
# kl:0.03414,lr_multiplier:0.444,loss:3.950517177581787,entropy:3.357151508331299,explained_var_old:0.332,explained_var_new:0.456
# batch i:95, episode_len:15
# kl:0.02502,lr_multiplier:0.444,loss:3.97977352142334,entropy:3.389606237411499,explained_var_old:0.294,explained_var_new:0.416
# batch i:96, episode_len:9
# kl:0.02359,lr_multiplier:0.444,loss:3.903090238571167,entropy:3.4012858867645264,explained_var_old:0.393,explained_var_new:0.505
# batch i:97, episode_len:21
# kl:0.02200,lr_multiplier:0.444,loss:3.907020092010498,entropy:3.2822933197021484,explained_var_old:0.324,explained_var_new:0.447
# batch i:98, episode_len:14
# kl:0.02863,lr_multiplier:0.444,loss:3.9191651344299316,entropy:3.371769666671753,explained_var_old:0.314,explained_var_new:0.446
# batch i:99, episode_len:13
# kl:0.01447,lr_multiplier:0.444,loss:3.9490675926208496,entropy:3.3525936603546143,explained_var_old:0.301,explained_var_new:0.409
# batch i:100, episode_len:19
# kl:0.02982,lr_multiplier:0.444,loss:3.8492326736450195,entropy:3.275111675262451,explained_var_old:0.300,explained_var_new:0.414
# current self-play batch: 100
# num_playouts:1000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
# batch i:101, episode_len:11
# kl:0.02060,lr_multiplier:0.444,loss:3.8647284507751465,entropy:3.3315179347991943,explained_var_old:0.406,explained_var_new:0.493
# batch i:102, episode_len:21
# kl:0.02853,lr_multiplier:0.444,loss:3.8672561645507812,entropy:3.325788736343384,explained_var_old:0.286,explained_var_new:0.436
# batch i:103, episode_len:10
# kl:0.02164,lr_multiplier:0.444,loss:3.826997756958008,entropy:3.3783986568450928,explained_var_old:0.395,explained_var_new:0.508
# batch i:104, episode_len:7
# kl:0.02354,lr_multiplier:0.444,loss:3.6727685928344727,entropy:3.2217178344726562,explained_var_old:0.529,explained_var_new:0.642
# batch i:105, episode_len:11
# kl:0.02128,lr_multiplier:0.444,loss:3.736281394958496,entropy:3.240976333618164,explained_var_old:0.426,explained_var_new:0.536
# batch i:106, episode_len:8
# kl:0.02925,lr_multiplier:0.444,loss:3.7346482276916504,entropy:3.3913018703460693,explained_var_old:0.467,explained_var_new:0.585
# batch i:107, episode_len:20
# kl:0.02041,lr_multiplier:0.444,loss:3.7817678451538086,entropy:3.254063367843628,explained_var_old:0.396,explained_var_new:0.518
# batch i:108, episode_len:13
# kl:0.02435,lr_multiplier:0.444,loss:3.7486660480499268,entropy:3.2429635524749756,explained_var_old:0.398,explained_var_new:0.531
# batch i:109, episode_len:18
# kl:0.01756,lr_multiplier:0.444,loss:3.701927661895752,entropy:3.256883382797241,explained_var_old:0.400,explained_var_new:0.536
# batch i:110, episode_len:9
# kl:0.02112,lr_multiplier:0.444,loss:3.61443829536438,entropy:3.2025375366210938,explained_var_old:0.469,explained_var_new:0.589
# batch i:111, episode_len:19
# kl:0.02525,lr_multiplier:0.444,loss:3.7931008338928223,entropy:3.254236936569214,explained_var_old:0.373,explained_var_new:0.497
# batch i:112, episode_len:24
# kl:0.02908,lr_multiplier:0.444,loss:3.643279552459717,entropy:3.1417601108551025,explained_var_old:0.408,explained_var_new:0.533
# batch i:113, episode_len:17
# kl:0.02434,lr_multiplier:0.444,loss:3.6370487213134766,entropy:3.1667356491088867,explained_var_old:0.411,explained_var_new:0.540
# batch i:114, episode_len:11
# kl:0.02794,lr_multiplier:0.444,loss:3.884401798248291,entropy:3.3022708892822266,explained_var_old:0.257,explained_var_new:0.402
# batch i:115, episode_len:30
# kl:0.02286,lr_multiplier:0.444,loss:3.694427728652954,entropy:3.2153351306915283,explained_var_old:0.404,explained_var_new:0.503
# batch i:116, episode_len:11
# kl:0.01864,lr_multiplier:0.444,loss:3.6174440383911133,entropy:3.130898952484131,explained_var_old:0.453,explained_var_new:0.568
# batch i:117, episode_len:18
# kl:0.02016,lr_multiplier:0.444,loss:3.766246795654297,entropy:3.3565690517425537,explained_var_old:0.386,explained_var_new:0.502
# batch i:118, episode_len:11
# kl:0.02161,lr_multiplier:0.444,loss:3.615183115005493,entropy:3.127387046813965,explained_var_old:0.434,explained_var_new:0.547
# batch i:119, episode_len:10
# kl:0.01189,lr_multiplier:0.444,loss:3.659639835357666,entropy:3.1968111991882324,explained_var_old:0.438,explained_var_new:0.539
# batch i:120, episode_len:11
# kl:0.01835,lr_multiplier:0.444,loss:3.594703197479248,entropy:3.0950679779052734,explained_var_old:0.418,explained_var_new:0.523
# batch i:121, episode_len:11
# kl:0.01160,lr_multiplier:0.444,loss:3.6802496910095215,entropy:3.141561508178711,explained_var_old:0.374,explained_var_new:0.484
# batch i:122, episode_len:11
# kl:0.01652,lr_multiplier:0.444,loss:3.676488161087036,entropy:3.23948073387146,explained_var_old:0.437,explained_var_new:0.544
# batch i:123, episode_len:7
# kl:0.01297,lr_multiplier:0.444,loss:3.6560256481170654,entropy:3.177125930786133,explained_var_old:0.461,explained_var_new:0.558
# batch i:124, episode_len:16
# kl:0.01781,lr_multiplier:0.444,loss:3.5946412086486816,entropy:3.1518990993499756,explained_var_old:0.464,explained_var_new:0.564
# batch i:125, episode_len:13
# kl:0.01731,lr_multiplier:0.444,loss:3.539504051208496,entropy:3.154148578643799,explained_var_old:0.530,explained_var_new:0.611
# batch i:126, episode_len:12
# kl:0.01913,lr_multiplier:0.444,loss:3.6372053623199463,entropy:3.1035454273223877,explained_var_old:0.407,explained_var_new:0.531
# batch i:127, episode_len:11
# kl:0.01504,lr_multiplier:0.444,loss:3.590456008911133,entropy:3.2050938606262207,explained_var_old:0.469,explained_var_new:0.599
# batch i:128, episode_len:16
# kl:0.01854,lr_multiplier:0.444,loss:3.5862090587615967,entropy:3.1767513751983643,explained_var_old:0.473,explained_var_new:0.572
# batch i:129, episode_len:12
# kl:0.01607,lr_multiplier:0.444,loss:3.652876853942871,entropy:3.2178359031677246,explained_var_old:0.398,explained_var_new:0.564
# batch i:130, episode_len:17
# kl:0.01511,lr_multiplier:0.444,loss:3.5854291915893555,entropy:3.1190061569213867,explained_var_old:0.427,explained_var_new:0.564
# batch i:131, episode_len:18
# kl:0.01797,lr_multiplier:0.444,loss:3.6511545181274414,entropy:3.1940500736236572,explained_var_old:0.344,explained_var_new:0.490
# batch i:132, episode_len:12
# kl:0.03081,lr_multiplier:0.444,loss:3.670743942260742,entropy:3.0196640491485596,explained_var_old:0.359,explained_var_new:0.492
# batch i:133, episode_len:9
# kl:0.02434,lr_multiplier:0.444,loss:3.606114625930786,entropy:3.2006607055664062,explained_var_old:0.384,explained_var_new:0.535
# batch i:134, episode_len:7
# kl:0.02356,lr_multiplier:0.444,loss:3.5540785789489746,entropy:3.0534982681274414,explained_var_old:0.407,explained_var_new:0.522
# batch i:135, episode_len:11
# kl:0.01616,lr_multiplier:0.444,loss:3.4498398303985596,entropy:3.051351547241211,explained_var_old:0.505,explained_var_new:0.599
# batch i:136, episode_len:8
# kl:0.01410,lr_multiplier:0.444,loss:3.5871410369873047,entropy:3.122385263442993,explained_var_old:0.363,explained_var_new:0.517
# batch i:137, episode_len:12
# kl:0.01944,lr_multiplier:0.444,loss:3.4833056926727295,entropy:3.032258987426758,explained_var_old:0.504,explained_var_new:0.610
# batch i:138, episode_len:12
# kl:0.03240,lr_multiplier:0.444,loss:3.538541555404663,entropy:3.1920642852783203,explained_var_old:0.469,explained_var_new:0.569
# batch i:139, episode_len:9
# kl:0.04077,lr_multiplier:0.296,loss:3.52641224861145,entropy:2.9897122383117676,explained_var_old:0.503,explained_var_new:0.621
# batch i:140, episode_len:14
# kl:0.04152,lr_multiplier:0.198,loss:3.5751845836639404,entropy:3.223987340927124,explained_var_old:0.535,explained_var_new:0.594
# batch i:141, episode_len:13
# kl:0.00956,lr_multiplier:0.296,loss:3.583453416824341,entropy:3.1582961082458496,explained_var_old:0.516,explained_var_new:0.568
# batch i:142, episode_len:15
# kl:0.02295,lr_multiplier:0.296,loss:3.478487253189087,entropy:2.9455666542053223,explained_var_old:0.478,explained_var_new:0.542
# batch i:143, episode_len:24
# kl:0.02893,lr_multiplier:0.296,loss:3.4707000255584717,entropy:3.05462646484375,explained_var_old:0.395,explained_var_new:0.504
# batch i:144, episode_len:9
# kl:0.02131,lr_multiplier:0.296,loss:3.498469114303589,entropy:2.9915575981140137,explained_var_old:0.421,explained_var_new:0.519
# batch i:145, episode_len:9
# kl:0.01171,lr_multiplier:0.296,loss:3.463183641433716,entropy:2.98093318939209,explained_var_old:0.420,explained_var_new:0.517
# batch i:146, episode_len:12
# kl:0.01842,lr_multiplier:0.296,loss:3.5172858238220215,entropy:3.1028125286102295,explained_var_old:0.413,explained_var_new:0.550
# batch i:147, episode_len:9
# kl:0.01258,lr_multiplier:0.296,loss:3.489213705062866,entropy:3.0102148056030273,explained_var_old:0.480,explained_var_new:0.538
# batch i:148, episode_len:7
# kl:0.01362,lr_multiplier:0.296,loss:3.470874309539795,entropy:3.0068047046661377,explained_var_old:0.456,explained_var_new:0.543
# batch i:149, episode_len:15
# kl:0.00888,lr_multiplier:0.444,loss:3.5395243167877197,entropy:3.01533842086792,explained_var_old:0.423,explained_var_new:0.492
# batch i:150, episode_len:8
# kl:0.01784,lr_multiplier:0.444,loss:3.452336549758911,entropy:3.0835108757019043,explained_var_old:0.505,explained_var_new:0.589
# current self-play batch: 150
# num_playouts:1000, win: 8, lose: 2, tie:0
# 发现新的最优策略，进行策略更新
# batch i:151, episode_len:13
# kl:0.01892,lr_multiplier:0.444,loss:3.484950542449951,entropy:3.0164036750793457,explained_var_old:0.459,explained_var_new:0.568
# batch i:152, episode_len:8
# kl:0.01670,lr_multiplier:0.444,loss:3.4942502975463867,entropy:3.0628576278686523,explained_var_old:0.459,explained_var_new:0.578
# batch i:153, episode_len:12
# kl:0.01561,lr_multiplier:0.444,loss:3.5371124744415283,entropy:3.0664985179901123,explained_var_old:0.389,explained_var_new:0.507
# batch i:154, episode_len:15
# kl:0.02437,lr_multiplier:0.444,loss:3.3685219287872314,entropy:2.9463634490966797,explained_var_old:0.448,explained_var_new:0.571
# batch i:155, episode_len:11
# kl:0.01843,lr_multiplier:0.444,loss:3.4217193126678467,entropy:2.9388267993927,explained_var_old:0.505,explained_var_new:0.584
# batch i:156, episode_len:9
# kl:0.01234,lr_multiplier:0.444,loss:3.4613804817199707,entropy:3.0724709033966064,explained_var_old:0.477,explained_var_new:0.591
# batch i:157, episode_len:7
# kl:0.02050,lr_multiplier:0.444,loss:3.3406808376312256,entropy:2.9068872928619385,explained_var_old:0.502,explained_var_new:0.600
# batch i:158, episode_len:11
# kl:0.01706,lr_multiplier:0.444,loss:3.452691078186035,entropy:2.9934797286987305,explained_var_old:0.423,explained_var_new:0.548
# batch i:159, episode_len:8
# kl:0.01464,lr_multiplier:0.444,loss:3.484156608581543,entropy:3.0384504795074463,explained_var_old:0.437,explained_var_new:0.579
# batch i:160, episode_len:17
# kl:0.01104,lr_multiplier:0.444,loss:3.420957326889038,entropy:3.001589298248291,explained_var_old:0.472,explained_var_new:0.581
# batch i:161, episode_len:9
# kl:0.01455,lr_multiplier:0.444,loss:3.4133055210113525,entropy:3.0430362224578857,explained_var_old:0.488,explained_var_new:0.583
# batch i:162, episode_len:8
# kl:0.01703,lr_multiplier:0.444,loss:3.4141592979431152,entropy:2.9070510864257812,explained_var_old:0.403,explained_var_new:0.537
# batch i:163, episode_len:11
# kl:0.01699,lr_multiplier:0.444,loss:3.3170604705810547,entropy:2.913010835647583,explained_var_old:0.527,explained_var_new:0.613
# batch i:164, episode_len:7
# kl:0.02307,lr_multiplier:0.444,loss:3.4104509353637695,entropy:3.0014710426330566,explained_var_old:0.450,explained_var_new:0.579
# batch i:165, episode_len:15
# kl:0.02621,lr_multiplier:0.444,loss:3.449093818664551,entropy:3.032796859741211,explained_var_old:0.491,explained_var_new:0.581
# batch i:166, episode_len:13
# kl:0.01989,lr_multiplier:0.444,loss:3.318425178527832,entropy:2.9686105251312256,explained_var_old:0.542,explained_var_new:0.641
# batch i:167, episode_len:9
# kl:0.02316,lr_multiplier:0.444,loss:3.412672519683838,entropy:2.9403257369995117,explained_var_old:0.522,explained_var_new:0.596
# batch i:168, episode_len:16
# kl:0.01405,lr_multiplier:0.444,loss:3.4109127521514893,entropy:2.951232433319092,explained_var_old:0.440,explained_var_new:0.544
# batch i:169, episode_len:7
# kl:0.01658,lr_multiplier:0.444,loss:3.4033474922180176,entropy:2.982304334640503,explained_var_old:0.472,explained_var_new:0.587
# batch i:170, episode_len:13
# kl:0.01920,lr_multiplier:0.444,loss:3.393836736679077,entropy:3.0382509231567383,explained_var_old:0.479,explained_var_new:0.573
# batch i:171, episode_len:12
# kl:0.01559,lr_multiplier:0.444,loss:3.448019504547119,entropy:2.9425106048583984,explained_var_old:0.427,explained_var_new:0.546
# batch i:172, episode_len:8
# kl:0.01815,lr_multiplier:0.444,loss:3.3741061687469482,entropy:2.9681358337402344,explained_var_old:0.451,explained_var_new:0.572
# batch i:173, episode_len:9
# kl:0.01648,lr_multiplier:0.444,loss:3.284874200820923,entropy:2.764796018600464,explained_var_old:0.432,explained_var_new:0.538
# batch i:174, episode_len:11
# kl:0.01544,lr_multiplier:0.444,loss:3.2185330390930176,entropy:2.9120092391967773,explained_var_old:0.559,explained_var_new:0.657
# batch i:175, episode_len:13
# kl:0.02322,lr_multiplier:0.444,loss:3.3064866065979004,entropy:2.7961015701293945,explained_var_old:0.450,explained_var_new:0.564
# batch i:176, episode_len:10
# kl:0.03635,lr_multiplier:0.444,loss:3.349855899810791,entropy:3.0634825229644775,explained_var_old:0.521,explained_var_new:0.612
# batch i:177, episode_len:7
# kl:0.03900,lr_multiplier:0.444,loss:3.2379493713378906,entropy:2.8020355701446533,explained_var_old:0.580,explained_var_new:0.652
# batch i:178, episode_len:7
# kl:0.01560,lr_multiplier:0.444,loss:3.297790050506592,entropy:2.916637659072876,explained_var_old:0.481,explained_var_new:0.577
# batch i:179, episode_len:7
# kl:0.01675,lr_multiplier:0.444,loss:3.2624454498291016,entropy:2.888136386871338,explained_var_old:0.504,explained_var_new:0.602
# batch i:180, episode_len:11
# kl:0.01814,lr_multiplier:0.444,loss:3.3093905448913574,entropy:2.8973352909088135,explained_var_old:0.545,explained_var_new:0.632
# batch i:181, episode_len:7
# kl:0.01511,lr_multiplier:0.444,loss:3.284848213195801,entropy:2.8937807083129883,explained_var_old:0.533,explained_var_new:0.624
# batch i:182, episode_len:12
# kl:0.02124,lr_multiplier:0.444,loss:3.270962715148926,entropy:2.9225964546203613,explained_var_old:0.516,explained_var_new:0.621
# batch i:183, episode_len:11
# kl:0.01857,lr_multiplier:0.444,loss:3.322845935821533,entropy:2.8249640464782715,explained_var_old:0.469,explained_var_new:0.562
# batch i:184, episode_len:13
# kl:0.01871,lr_multiplier:0.444,loss:3.319777488708496,entropy:3.0019171237945557,explained_var_old:0.528,explained_var_new:0.629
# batch i:185, episode_len:12
# kl:0.02478,lr_multiplier:0.444,loss:3.231110095977783,entropy:2.7761759757995605,explained_var_old:0.439,explained_var_new:0.565
# batch i:186, episode_len:7
# kl:0.01590,lr_multiplier:0.444,loss:3.233750104904175,entropy:2.9317851066589355,explained_var_old:0.552,explained_var_new:0.651
# batch i:187, episode_len:7
# kl:0.02213,lr_multiplier:0.444,loss:3.238557815551758,entropy:2.798525333404541,explained_var_old:0.488,explained_var_new:0.581
# batch i:188, episode_len:8
# kl:0.01871,lr_multiplier:0.444,loss:3.2870430946350098,entropy:2.772362232208252,explained_var_old:0.479,explained_var_new:0.557
# batch i:189, episode_len:8
# kl:0.01330,lr_multiplier:0.444,loss:3.225524425506592,entropy:2.826091766357422,explained_var_old:0.470,explained_var_new:0.583
# batch i:190, episode_len:12
# kl:0.01256,lr_multiplier:0.444,loss:3.179974317550659,entropy:2.817173719406128,explained_var_old:0.537,explained_var_new:0.601
# batch i:191, episode_len:11
# kl:0.01151,lr_multiplier:0.444,loss:3.276484251022339,entropy:2.8279354572296143,explained_var_old:0.502,explained_var_new:0.598
# batch i:192, episode_len:11
# kl:0.01157,lr_multiplier:0.444,loss:3.2355008125305176,entropy:2.8067805767059326,explained_var_old:0.490,explained_var_new:0.603
# batch i:193, episode_len:9
# kl:0.01487,lr_multiplier:0.444,loss:3.2892184257507324,entropy:2.8631582260131836,explained_var_old:0.478,explained_var_new:0.552
# batch i:194, episode_len:21
# kl:0.01203,lr_multiplier:0.444,loss:3.1710422039031982,entropy:2.712877035140991,explained_var_old:0.506,explained_var_new:0.585
# batch i:195, episode_len:10
# kl:0.01586,lr_multiplier:0.444,loss:3.1752922534942627,entropy:2.924330949783325,explained_var_old:0.588,explained_var_new:0.661
# batch i:196, episode_len:7
# kl:0.02521,lr_multiplier:0.444,loss:3.188302993774414,entropy:2.718502998352051,explained_var_old:0.562,explained_var_new:0.644
# batch i:197, episode_len:9
# kl:0.02029,lr_multiplier:0.444,loss:3.216064929962158,entropy:2.824690341949463,explained_var_old:0.502,explained_var_new:0.604
# batch i:198, episode_len:18
# kl:0.01729,lr_multiplier:0.444,loss:3.1703107357025146,entropy:2.8066916465759277,explained_var_old:0.532,explained_var_new:0.617
# batch i:199, episode_len:9
# kl:0.01274,lr_multiplier:0.444,loss:3.3251304626464844,entropy:2.9591827392578125,explained_var_old:0.497,explained_var_new:0.590
# batch i:200, episode_len:9
# kl:0.01660,lr_multiplier:0.444,loss:3.140699625015259,entropy:2.6920337677001953,explained_var_old:0.495,explained_var_new:0.598
# current self-play batch: 200
# num_playouts:1000, win: 10, lose: 0, tie:0
# 发现新的最优策略，进行策略更新
# batch i:201, episode_len:9
# kl:0.01699,lr_multiplier:0.444,loss:3.1798675060272217,entropy:2.8036041259765625,explained_var_old:0.508,explained_var_new:0.605
# batch i:202, episode_len:9
# kl:0.00997,lr_multiplier:0.667,loss:3.255831241607666,entropy:2.852553606033325,explained_var_old:0.500,explained_var_new:0.576
# batch i:203, episode_len:11
# kl:0.01786,lr_multiplier:0.667,loss:3.1333978176116943,entropy:2.6758131980895996,explained_var_old:0.464,explained_var_new:0.576
# batch i:204, episode_len:11
# kl:0.02633,lr_multiplier:0.667,loss:3.177415370941162,entropy:2.7888965606689453,explained_var_old:0.538,explained_var_new:0.641
# batch i:205, episode_len:11
# kl:0.02745,lr_multiplier:0.667,loss:3.0845842361450195,entropy:2.7191033363342285,explained_var_old:0.577,explained_var_new:0.668
# batch i:206, episode_len:9
# kl:0.02418,lr_multiplier:0.667,loss:3.0893821716308594,entropy:2.8184285163879395,explained_var_old:0.568,explained_var_new:0.684
# batch i:207, episode_len:8
# kl:0.02872,lr_multiplier:0.667,loss:3.233900547027588,entropy:2.8428919315338135,explained_var_old:0.524,explained_var_new:0.634
# batch i:208, episode_len:8
# kl:0.02400,lr_multiplier:0.667,loss:3.1381099224090576,entropy:2.766637086868286,explained_var_old:0.519,explained_var_new:0.614
# batch i:209, episode_len:9
# kl:0.02277,lr_multiplier:0.667,loss:3.067312002182007,entropy:2.6527700424194336,explained_var_old:0.457,explained_var_new:0.594
# batch i:210, episode_len:18
# kl:0.03310,lr_multiplier:0.667,loss:3.1948397159576416,entropy:2.794785261154175,explained_var_old:0.471,explained_var_new:0.600
# batch i:211, episode_len:11
# kl:0.01767,lr_multiplier:0.667,loss:3.252023935317993,entropy:2.86856746673584,explained_var_old:0.464,explained_var_new:0.583
# batch i:212, episode_len:8
# kl:0.03684,lr_multiplier:0.667,loss:3.102418899536133,entropy:2.6546061038970947,explained_var_old:0.490,explained_var_new:0.620
# batch i:213, episode_len:10
# kl:0.03610,lr_multiplier:0.667,loss:3.199740171432495,entropy:2.8492119312286377,explained_var_old:0.470,explained_var_new:0.586
# batch i:214, episode_len:11
# kl:0.02364,lr_multiplier:0.667,loss:3.222397565841675,entropy:2.8733153343200684,explained_var_old:0.472,explained_var_new:0.609
# batch i:215, episode_len:9
# kl:0.04347,lr_multiplier:0.444,loss:3.091931104660034,entropy:2.644282579421997,explained_var_old:0.493,explained_var_new:0.635
# batch i:216, episode_len:11
# kl:0.01521,lr_multiplier:0.444,loss:3.2428836822509766,entropy:2.828047752380371,explained_var_old:0.454,explained_var_new:0.572
# batch i:217, episode_len:9
# kl:0.01767,lr_multiplier:0.444,loss:3.0870044231414795,entropy:2.634836435317993,explained_var_old:0.462,explained_var_new:0.596
# batch i:218, episode_len:7
# kl:0.01927,lr_multiplier:0.444,loss:3.1066079139709473,entropy:2.7853779792785645,explained_var_old:0.540,explained_var_new:0.625
# batch i:219, episode_len:11
# kl:0.01606,lr_multiplier:0.444,loss:3.094310760498047,entropy:2.604074716567993,explained_var_old:0.511,explained_var_new:0.591
# batch i:220, episode_len:9
# kl:0.02744,lr_multiplier:0.444,loss:3.2349467277526855,entropy:2.9286715984344482,explained_var_old:0.447,explained_var_new:0.579
# batch i:221, episode_len:9
# kl:0.01803,lr_multiplier:0.444,loss:3.1399433612823486,entropy:2.650055408477783,explained_var_old:0.479,explained_var_new:0.589
# batch i:222, episode_len:13
# kl:0.01995,lr_multiplier:0.444,loss:3.1684770584106445,entropy:2.796729564666748,explained_var_old:0.490,explained_var_new:0.584
# batch i:223, episode_len:7
# kl:0.01676,lr_multiplier:0.444,loss:3.145254611968994,entropy:2.5990142822265625,explained_var_old:0.430,explained_var_new:0.562
# batch i:224, episode_len:8
# kl:0.01417,lr_multiplier:0.444,loss:3.1079952716827393,entropy:2.8269002437591553,explained_var_old:0.541,explained_var_new:0.619
# batch i:225, episode_len:13
# kl:0.01590,lr_multiplier:0.444,loss:3.058626651763916,entropy:2.5961971282958984,explained_var_old:0.502,explained_var_new:0.588
# batch i:226, episode_len:9
# kl:0.01586,lr_multiplier:0.444,loss:3.1293492317199707,entropy:2.705667495727539,explained_var_old:0.446,explained_var_new:0.578
# batch i:227, episode_len:19
# kl:0.02232,lr_multiplier:0.444,loss:3.1775622367858887,entropy:2.8350298404693604,explained_var_old:0.518,explained_var_new:0.603
# batch i:228, episode_len:12
# kl:0.02656,lr_multiplier:0.444,loss:3.055403470993042,entropy:2.632040500640869,explained_var_old:0.524,explained_var_new:0.604
# batch i:229, episode_len:9
# kl:0.01685,lr_multiplier:0.444,loss:3.034590005874634,entropy:2.608668565750122,explained_var_old:0.517,explained_var_new:0.620
# batch i:230, episode_len:11
# kl:0.01486,lr_multiplier:0.444,loss:3.0176689624786377,entropy:2.5860116481781006,explained_var_old:0.533,explained_var_new:0.608
# batch i:231, episode_len:9
# kl:0.01557,lr_multiplier:0.444,loss:3.1433839797973633,entropy:2.8064041137695312,explained_var_old:0.490,explained_var_new:0.582
# batch i:232, episode_len:10
# kl:0.01442,lr_multiplier:0.444,loss:3.0208582878112793,entropy:2.586085796356201,explained_var_old:0.505,explained_var_new:0.599
# batch i:233, episode_len:7
# kl:0.01160,lr_multiplier:0.444,loss:3.013603448867798,entropy:2.612860918045044,explained_var_old:0.573,explained_var_new:0.640
# batch i:234, episode_len:19
# kl:0.01741,lr_multiplier:0.444,loss:3.112816095352173,entropy:2.7267980575561523,explained_var_old:0.481,explained_var_new:0.588
# batch i:235, episode_len:13
# kl:0.01152,lr_multiplier:0.444,loss:3.041834831237793,entropy:2.5965304374694824,explained_var_old:0.487,explained_var_new:0.575
# batch i:236, episode_len:9
# kl:0.01214,lr_multiplier:0.444,loss:3.0441935062408447,entropy:2.598059892654419,explained_var_old:0.494,explained_var_new:0.579
# batch i:237, episode_len:10
# kl:0.01256,lr_multiplier:0.444,loss:3.031676769256592,entropy:2.63981556892395,explained_var_old:0.442,explained_var_new:0.569
# batch i:238, episode_len:9
# kl:0.01477,lr_multiplier:0.444,loss:3.0436925888061523,entropy:2.5749802589416504,explained_var_old:0.488,explained_var_new:0.578
# batch i:239, episode_len:8
# kl:0.02166,lr_multiplier:0.444,loss:3.096522331237793,entropy:2.6607003211975098,explained_var_old:0.418,explained_var_new:0.514
# batch i:240, episode_len:11
# kl:0.03182,lr_multiplier:0.444,loss:3.024441719055176,entropy:2.4737789630889893,explained_var_old:0.444,explained_var_new:0.584
# batch i:241, episode_len:16
# kl:0.04293,lr_multiplier:0.296,loss:3.1042935848236084,entropy:2.7520456314086914,explained_var_old:0.396,explained_var_new:0.519
# batch i:242, episode_len:13
# kl:0.02259,lr_multiplier:0.296,loss:3.1226651668548584,entropy:2.6007535457611084,explained_var_old:0.477,explained_var_new:0.554
# batch i:243, episode_len:11
# kl:0.01198,lr_multiplier:0.296,loss:3.0913987159729004,entropy:2.6994097232818604,explained_var_old:0.463,explained_var_new:0.539
# batch i:244, episode_len:7
# kl:0.01017,lr_multiplier:0.296,loss:3.1247949600219727,entropy:2.682969331741333,explained_var_old:0.506,explained_var_new:0.568
# batch i:245, episode_len:7
# kl:0.01618,lr_multiplier:0.296,loss:3.0406904220581055,entropy:2.5540521144866943,explained_var_old:0.481,explained_var_new:0.556
# batch i:246, episode_len:12
# kl:0.02327,lr_multiplier:0.296,loss:3.1444778442382812,entropy:2.6632466316223145,explained_var_old:0.438,explained_var_new:0.515
# batch i:247, episode_len:7
# kl:0.01446,lr_multiplier:0.296,loss:3.0597684383392334,entropy:2.6501376628875732,explained_var_old:0.482,explained_var_new:0.539
# batch i:248, episode_len:10
# kl:0.02123,lr_multiplier:0.296,loss:3.0396575927734375,entropy:2.4788284301757812,explained_var_old:0.472,explained_var_new:0.529
# batch i:249, episode_len:11
# kl:0.02463,lr_multiplier:0.296,loss:3.068096876144409,entropy:2.6810905933380127,explained_var_old:0.479,explained_var_new:0.531
# batch i:250, episode_len:7
# kl:0.01158,lr_multiplier:0.296,loss:3.054441452026367,entropy:2.5742990970611572,explained_var_old:0.471,explained_var_new:0.548
# current self-play batch: 250
# num_playouts:2000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
# batch i:251, episode_len:7
# kl:0.01127,lr_multiplier:0.296,loss:3.0479490756988525,entropy:2.5926592350006104,explained_var_old:0.474,explained_var_new:0.555
# batch i:252, episode_len:9
# kl:0.01485,lr_multiplier:0.296,loss:3.020528793334961,entropy:2.6626415252685547,explained_var_old:0.544,explained_var_new:0.601
# batch i:253, episode_len:16
# kl:0.01689,lr_multiplier:0.296,loss:2.9602248668670654,entropy:2.475928783416748,explained_var_old:0.493,explained_var_new:0.548
# batch i:254, episode_len:7
# kl:0.00772,lr_multiplier:0.444,loss:2.832150936126709,entropy:2.34755277633667,explained_var_old:0.471,explained_var_new:0.550
# batch i:255, episode_len:11
# kl:0.02623,lr_multiplier:0.444,loss:3.0275185108184814,entropy:2.656736373901367,explained_var_old:0.448,explained_var_new:0.534
# batch i:256, episode_len:16
# kl:0.03410,lr_multiplier:0.444,loss:2.9401097297668457,entropy:2.43997859954834,explained_var_old:0.474,explained_var_new:0.574
# batch i:257, episode_len:15
# kl:0.01485,lr_multiplier:0.444,loss:2.981746196746826,entropy:2.5462543964385986,explained_var_old:0.482,explained_var_new:0.558
# batch i:258, episode_len:9
# kl:0.01433,lr_multiplier:0.444,loss:3.016455888748169,entropy:2.6291167736053467,explained_var_old:0.476,explained_var_new:0.573
# batch i:259, episode_len:13
# kl:0.00920,lr_multiplier:0.667,loss:3.050797939300537,entropy:2.6032450199127197,explained_var_old:0.436,explained_var_new:0.565
# batch i:260, episode_len:7
# kl:0.02001,lr_multiplier:0.667,loss:3.079310417175293,entropy:2.6073970794677734,explained_var_old:0.427,explained_var_new:0.556
# batch i:261, episode_len:11
# kl:0.02147,lr_multiplier:0.667,loss:2.86985445022583,entropy:2.4818778038024902,explained_var_old:0.509,explained_var_new:0.638
# batch i:262, episode_len:7
# kl:0.02028,lr_multiplier:0.667,loss:2.9922542572021484,entropy:2.6241366863250732,explained_var_old:0.408,explained_var_new:0.580
# batch i:263, episode_len:14
# kl:0.01992,lr_multiplier:0.667,loss:3.0003201961517334,entropy:2.4518301486968994,explained_var_old:0.358,explained_var_new:0.494
# batch i:264, episode_len:12
# kl:0.02237,lr_multiplier:0.667,loss:3.0346839427948,entropy:2.5780646800994873,explained_var_old:0.393,explained_var_new:0.546
# batch i:265, episode_len:8
# kl:0.01864,lr_multiplier:0.667,loss:3.0126936435699463,entropy:2.60884165763855,explained_var_old:0.451,explained_var_new:0.553
# batch i:266, episode_len:11
# kl:0.02174,lr_multiplier:0.667,loss:3.0220463275909424,entropy:2.4787886142730713,explained_var_old:0.384,explained_var_new:0.501
# batch i:267, episode_len:29
# kl:0.02686,lr_multiplier:0.667,loss:3.0686628818511963,entropy:2.5634920597076416,explained_var_old:0.373,explained_var_new:0.497
# batch i:268, episode_len:7
# kl:0.02815,lr_multiplier:0.667,loss:3.0291459560394287,entropy:2.6212100982666016,explained_var_old:0.379,explained_var_new:0.534
# batch i:269, episode_len:13
# kl:0.03131,lr_multiplier:0.667,loss:2.9817771911621094,entropy:2.5484704971313477,explained_var_old:0.445,explained_var_new:0.561
# batch i:270, episode_len:7
# kl:0.02229,lr_multiplier:0.667,loss:3.0491414070129395,entropy:2.5538992881774902,explained_var_old:0.418,explained_var_new:0.519
# batch i:271, episode_len:7
# kl:0.02871,lr_multiplier:0.667,loss:2.8831787109375,entropy:2.524038314819336,explained_var_old:0.506,explained_var_new:0.651
# batch i:272, episode_len:7
# kl:0.02586,lr_multiplier:0.667,loss:2.9006240367889404,entropy:2.444352388381958,explained_var_old:0.469,explained_var_new:0.588
# batch i:273, episode_len:7
# kl:0.01912,lr_multiplier:0.667,loss:2.9629838466644287,entropy:2.5390267372131348,explained_var_old:0.466,explained_var_new:0.582
# batch i:274, episode_len:17
# kl:0.03303,lr_multiplier:0.667,loss:2.9263672828674316,entropy:2.578725576400757,explained_var_old:0.476,explained_var_new:0.570
# batch i:275, episode_len:7
# kl:0.04202,lr_multiplier:0.444,loss:2.8823468685150146,entropy:2.4365878105163574,explained_var_old:0.498,explained_var_new:0.599
# batch i:276, episode_len:15
# kl:0.02582,lr_multiplier:0.444,loss:2.897014856338501,entropy:2.5058960914611816,explained_var_old:0.462,explained_var_new:0.572
# batch i:277, episode_len:7
# kl:0.02090,lr_multiplier:0.444,loss:2.865360975265503,entropy:2.474301815032959,explained_var_old:0.476,explained_var_new:0.573
# batch i:278, episode_len:11
# kl:0.03001,lr_multiplier:0.444,loss:2.8578319549560547,entropy:2.3870890140533447,explained_var_old:0.496,explained_var_new:0.577
# batch i:279, episode_len:7
# kl:0.03052,lr_multiplier:0.444,loss:2.9412031173706055,entropy:2.573902130126953,explained_var_old:0.539,explained_var_new:0.614
# batch i:280, episode_len:10
# kl:0.03054,lr_multiplier:0.444,loss:2.9009130001068115,entropy:2.4486141204833984,explained_var_old:0.471,explained_var_new:0.563
# batch i:281, episode_len:7
# kl:0.01698,lr_multiplier:0.444,loss:2.8862576484680176,entropy:2.462653398513794,explained_var_old:0.520,explained_var_new:0.598
# batch i:282, episode_len:15
# kl:0.02129,lr_multiplier:0.444,loss:2.7678394317626953,entropy:2.3864948749542236,explained_var_old:0.527,explained_var_new:0.614
# batch i:283, episode_len:13
# kl:0.02769,lr_multiplier:0.444,loss:2.879894733428955,entropy:2.5945849418640137,explained_var_old:0.554,explained_var_new:0.641
# batch i:284, episode_len:7
# kl:0.03842,lr_multiplier:0.444,loss:2.8999381065368652,entropy:2.3938074111938477,explained_var_old:0.511,explained_var_new:0.600
# batch i:285, episode_len:7
# kl:0.03602,lr_multiplier:0.444,loss:2.8905768394470215,entropy:2.6133806705474854,explained_var_old:0.528,explained_var_new:0.602
# batch i:286, episode_len:11
# kl:0.04532,lr_multiplier:0.296,loss:2.7568857669830322,entropy:2.287243366241455,explained_var_old:0.556,explained_var_new:0.640
# batch i:287, episode_len:7
# kl:0.02687,lr_multiplier:0.296,loss:2.9088122844696045,entropy:2.4531185626983643,explained_var_old:0.512,explained_var_new:0.571
# batch i:288, episode_len:14
# kl:0.01620,lr_multiplier:0.296,loss:2.9399631023406982,entropy:2.5018632411956787,explained_var_old:0.522,explained_var_new:0.578
# batch i:289, episode_len:11
# kl:0.01482,lr_multiplier:0.296,loss:2.801403045654297,entropy:2.490478515625,explained_var_old:0.556,explained_var_new:0.625
# batch i:290, episode_len:8
# kl:0.00866,lr_multiplier:0.444,loss:2.8393523693084717,entropy:2.449983596801758,explained_var_old:0.524,explained_var_new:0.600
# batch i:291, episode_len:13
# kl:0.02132,lr_multiplier:0.444,loss:2.7206485271453857,entropy:2.336453437805176,explained_var_old:0.567,explained_var_new:0.641
# batch i:292, episode_len:22
# kl:0.03752,lr_multiplier:0.444,loss:2.876979351043701,entropy:2.559332847595215,explained_var_old:0.510,explained_var_new:0.594
# batch i:293, episode_len:7
# kl:0.03119,lr_multiplier:0.444,loss:2.8158648014068604,entropy:2.32149076461792,explained_var_old:0.512,explained_var_new:0.593
# batch i:294, episode_len:11
# kl:0.01512,lr_multiplier:0.444,loss:2.8422534465789795,entropy:2.445216417312622,explained_var_old:0.463,explained_var_new:0.571
# batch i:295, episode_len:12
# kl:0.02530,lr_multiplier:0.444,loss:2.812704563140869,entropy:2.4519741535186768,explained_var_old:0.502,explained_var_new:0.603
# batch i:296, episode_len:15
# kl:0.03840,lr_multiplier:0.444,loss:2.910489082336426,entropy:2.425342082977295,explained_var_old:0.495,explained_var_new:0.580
# batch i:297, episode_len:9
# kl:0.02025,lr_multiplier:0.444,loss:2.8106868267059326,entropy:2.5280797481536865,explained_var_old:0.546,explained_var_new:0.649
# batch i:298, episode_len:7
# kl:0.01732,lr_multiplier:0.444,loss:2.8312413692474365,entropy:2.4171364307403564,explained_var_old:0.493,explained_var_new:0.585
# batch i:299, episode_len:7
# kl:0.02085,lr_multiplier:0.444,loss:2.8394153118133545,entropy:2.4190030097961426,explained_var_old:0.509,explained_var_new:0.597
# batch i:300, episode_len:13
# kl:0.02563,lr_multiplier:0.444,loss:2.8388333320617676,entropy:2.3999369144439697,explained_var_old:0.460,explained_var_new:0.564
# current self-play batch: 300
# num_playouts:2000, win: 7, lose: 3, tie:0
# batch i:301, episode_len:7
# kl:0.01905,lr_multiplier:0.444,loss:2.795921564102173,entropy:2.385296583175659,explained_var_old:0.513,explained_var_new:0.601
# batch i:302, episode_len:10
# kl:0.02607,lr_multiplier:0.444,loss:2.871978521347046,entropy:2.5302765369415283,explained_var_old:0.526,explained_var_new:0.608
# batch i:303, episode_len:7
# ...
# current self-play batch: 400
# num_playouts:2000, win: 9, lose: 1, tie:0
# 发现新的最优策略，进行策略更新
# batch i:401, episode_len:25
# kl:0.01609,lr_multiplier:0.296,loss:2.4362564086914062,entropy:2.074162483215332,explained_var_old:0.550,explained_var_new:0.644
# batch i:402, episode_len:24
# kl:0.02221,lr_multiplier:0.296,loss:2.6369049549102783,entropy:2.2589306831359863,explained_var_old:0.561,explained_var_new:0.615
# batch i:403, episode_len:13
# kl:0.02499,lr_multiplier:0.296,loss:2.5028367042541504,entropy:2.1898128986358643,explained_var_old:0.592,explained_var_new:0.668
# batch i:404, episode_len:17
# kl:0.03592,lr_multiplier:0.296,loss:2.5257318019866943,entropy:2.1095073223114014,explained_var_old:0.530,explained_var_new:0.585
# batch i:405, episode_len:9
# kl:0.02320,lr_multiplier:0.296,loss:2.4601573944091797,entropy:2.0855178833007812,explained_var_old:0.529,explained_var_new:0.600
# batch i:406, episode_len:9
# kl:0.01526,lr_multiplier:0.296,loss:2.6092545986175537,entropy:2.1570491790771484,explained_var_old:0.519,explained_var_new:0.601
# batch i:407, episode_len:12
# kl:0.01290,lr_multiplier:0.296,loss:2.5325069427490234,entropy:2.207119941711426,explained_var_old:0.523,explained_var_new:0.597
# batch i:408, episode_len:7
# kl:0.01251,lr_multiplier:0.296,loss:2.5638725757598877,entropy:2.1260921955108643,explained_var_old:0.512,explained_var_new:0.584
# batch i:409, episode_len:17
# kl:0.01677,lr_multiplier:0.296,loss:2.600162982940674,entropy:2.1517720222473145,explained_var_old:0.468,explained_var_new:0.574
# batch i:410, episode_len:8
# kl:0.01555,lr_multiplier:0.296,loss:2.5134260654449463,entropy:2.1924386024475098,explained_var_old:0.528,explained_var_new:0.618
# batch i:411, episode_len:7
# kl:0.02097,lr_multiplier:0.296,loss:2.7297208309173584,entropy:2.2833306789398193,explained_var_old:0.414,explained_var_new:0.554
# batch i:412, episode_len:8
# kl:0.03544,lr_multiplier:0.296,loss:2.518162727355957,entropy:2.120934009552002,explained_var_old:0.530,explained_var_new:0.592
# batch i:413, episode_len:7
# kl:0.02948,lr_multiplier:0.296,loss:2.5164008140563965,entropy:2.1507933139801025,explained_var_old:0.523,explained_var_new:0.608
# batch i:414, episode_len:9
# kl:0.03363,lr_multiplier:0.296,loss:2.5245535373687744,entropy:2.045193672180176,explained_var_old:0.485,explained_var_new:0.558
# batch i:415, episode_len:13
# kl:0.02851,lr_multiplier:0.296,loss:2.542391777038574,entropy:2.1766231060028076,explained_var_old:0.552,explained_var_new:0.621
# batch i:416, episode_len:9
# kl:0.01363,lr_multiplier:0.296,loss:2.5646214485168457,entropy:2.1233837604522705,explained_var_old:0.492,explained_var_new:0.570
# batch i:417, episode_len:7
# kl:0.01335,lr_multiplier:0.296,loss:2.4714603424072266,entropy:2.1408772468566895,explained_var_old:0.548,explained_var_new:0.620
# batch i:418, episode_len:9
# kl:0.01021,lr_multiplier:0.296,loss:2.5214033126831055,entropy:2.12878155708313,explained_var_old:0.525,explained_var_new:0.602
# batch i:419, episode_len:7
# kl:0.01513,lr_multiplier:0.296,loss:2.42922306060791,entropy:2.04325008392334,explained_var_old:0.579,explained_var_new:0.644
# batch i:420, episode_len:8
# kl:0.01305,lr_multiplier:0.296,loss:2.4912190437316895,entropy:2.1159090995788574,explained_var_old:0.506,explained_var_new:0.576
# batch i:421, episode_len:8
# kl:0.01064,lr_multiplier:0.296,loss:2.534266471862793,entropy:2.138031244277954,explained_var_old:0.585,explained_var_new:0.647
# batch i:422, episode_len:16
# kl:0.01349,lr_multiplier:0.296,loss:2.3451199531555176,entropy:1.9674537181854248,explained_var_old:0.572,explained_var_new:0.607
# batch i:423, episode_len:10
# kl:0.01728,lr_multiplier:0.296,loss:2.5271315574645996,entropy:2.10886549949646,explained_var_old:0.540,explained_var_new:0.596
# batch i:424, episode_len:7
# kl:0.01487,lr_multiplier:0.296,loss:2.4784939289093018,entropy:2.0936203002929688,explained_var_old:0.510,explained_var_new:0.586
# batch i:425, episode_len:9
# kl:0.01877,lr_multiplier:0.296,loss:2.4673001766204834,entropy:2.114612102508545,explained_var_old:0.554,explained_var_new:0.626
# batch i:426, episode_len:13
# kl:0.01657,lr_multiplier:0.296,loss:2.49531888961792,entropy:2.0829126834869385,explained_var_old:0.591,explained_var_new:0.639
# batch i:427, episode_len:7
# kl:0.01269,lr_multiplier:0.296,loss:2.466416358947754,entropy:2.1039083003997803,explained_var_old:0.559,explained_var_new:0.614
# batch i:428, episode_len:11
# kl:0.01115,lr_multiplier:0.296,loss:2.4782533645629883,entropy:2.182771682739258,explained_var_old:0.577,explained_var_new:0.645
# batch i:429, episode_len:13
# kl:0.01660,lr_multiplier:0.296,loss:2.5081114768981934,entropy:2.0311923027038574,explained_var_old:0.531,explained_var_new:0.584
# batch i:430, episode_len:8
# kl:0.01168,lr_multiplier:0.296,loss:2.4351868629455566,entropy:2.002554416656494,explained_var_old:0.544,explained_var_new:0.598
# batch i:431, episode_len:9
# kl:0.01250,lr_multiplier:0.296,loss:2.481290340423584,entropy:2.1425092220306396,explained_var_old:0.611,explained_var_new:0.661
# batch i:432, episode_len:10
# kl:0.01393,lr_multiplier:0.296,loss:2.456728458404541,entropy:2.058912754058838,explained_var_old:0.525,explained_var_new:0.590
# batch i:433, episode_len:12
# kl:0.01217,lr_multiplier:0.296,loss:2.5009889602661133,entropy:2.0999457836151123,explained_var_old:0.568,explained_var_new:0.620
# batch i:434, episode_len:7
# kl:0.01599,lr_multiplier:0.296,loss:2.5281105041503906,entropy:2.145050525665283,explained_var_old:0.543,explained_var_new:0.613
# batch i:435, episode_len:7
# kl:0.01511,lr_multiplier:0.296,loss:2.4618263244628906,entropy:2.114891767501831,explained_var_old:0.590,explained_var_new:0.639
# batch i:436, episode_len:7
# kl:0.01349,lr_multiplier:0.296,loss:2.376814842224121,entropy:2.1032979488372803,explained_var_old:0.650,explained_var_new:0.698
# batch i:437, episode_len:7
# kl:0.01341,lr_multiplier:0.296,loss:2.3219079971313477,entropy:1.9576537609100342,explained_var_old:0.575,explained_var_new:0.622
# batch i:438, episode_len:7
# kl:0.01167,lr_multiplier:0.296,loss:2.287195920944214,entropy:1.973404049873352,explained_var_old:0.608,explained_var_new:0.669
# batch i:439, episode_len:13
# kl:0.00812,lr_multiplier:0.444,loss:2.3718607425689697,entropy:2.013554573059082,explained_var_old:0.623,explained_var_new:0.676
# batch i:440, episode_len:10
# kl:0.01719,lr_multiplier:0.444,loss:2.5116705894470215,entropy:2.126703977584839,explained_var_old:0.540,explained_var_new:0.614
# batch i:441, episode_len:8
# kl:0.02610,lr_multiplier:0.444,loss:2.381371259689331,entropy:2.0908896923065186,explained_var_old:0.588,explained_var_new:0.658
# batch i:442, episode_len:10
# kl:0.02404,lr_multiplier:0.444,loss:2.4477319717407227,entropy:2.1221203804016113,explained_var_old:0.644,explained_var_new:0.693
# batch i:443, episode_len:9
# kl:0.01561,lr_multiplier:0.444,loss:2.3413047790527344,entropy:2.037179946899414,explained_var_old:0.561,explained_var_new:0.635
# batch i:444, episode_len:9
# kl:0.02915,lr_multiplier:0.444,loss:2.315694808959961,entropy:1.9155807495117188,explained_var_old:0.592,explained_var_new:0.667
# batch i:445, episode_len:11
# kl:0.02973,lr_multiplier:0.444,loss:2.441208839416504,entropy:2.1048269271850586,explained_var_old:0.593,explained_var_new:0.656
# batch i:446, episode_len:17
# kl:0.02082,lr_multiplier:0.444,loss:2.303738594055176,entropy:2.061030864715576,explained_var_old:0.606,explained_var_new:0.674
# batch i:447, episode_len:11
# kl:0.01975,lr_multiplier:0.444,loss:2.4441001415252686,entropy:2.050636053085327,explained_var_old:0.484,explained_var_new:0.595
# batch i:448, episode_len:7
# kl:0.02194,lr_multiplier:0.444,loss:2.398460626602173,entropy:1.9660084247589111,explained_var_old:0.557,explained_var_new:0.646
# batch i:449, episode_len:7
# kl:0.02970,lr_multiplier:0.444,loss:2.3221940994262695,entropy:1.970877766609192,explained_var_old:0.562,explained_var_new:0.664
# batch i:450, episode_len:9
# kl:0.01697,lr_multiplier:0.444,loss:2.346341848373413,entropy:2.0634751319885254,explained_var_old:0.571,explained_var_new:0.635
# current self-play batch: 450
# num_playouts:2000, win: 10, lose: 0, tie:0
# 发现新的最优策略，进行策略更新
# batch i:451, episode_len:14
# kl:0.03073,lr_multiplier:0.444,loss:2.36088490486145,entropy:2.0501813888549805,explained_var_old:0.595,explained_var_new:0.685
# batch i:452, episode_len:10
# kl:0.02607,lr_multiplier:0.444,loss:2.482820749282837,entropy:2.0581347942352295,explained_var_old:0.525,explained_var_new:0.621
# batch i:453, episode_len:8
# kl:0.02114,lr_multiplier:0.444,loss:2.2978336811065674,entropy:1.973944067955017,explained_var_old:0.582,explained_var_new:0.662
# batch i:454, episode_len:7
# kl:0.02970,lr_multiplier:0.444,loss:2.4131102561950684,entropy:2.097839117050171,explained_var_old:0.545,explained_var_new:0.633
# batch i:455, episode_len:8
# kl:0.02131,lr_multiplier:0.444,loss:2.3788492679595947,entropy:2.0386033058166504,explained_var_old:0.594,explained_var_new:0.670
# batch i:456, episode_len:16
# kl:0.01550,lr_multiplier:0.444,loss:2.4474358558654785,entropy:2.1044905185699463,explained_var_old:0.534,explained_var_new:0.611
# batch i:457, episode_len:13
# kl:0.03339,lr_multiplier:0.444,loss:2.442000389099121,entropy:2.0406227111816406,explained_var_old:0.582,explained_var_new:0.649
# batch i:458, episode_len:19
# kl:0.03311,lr_multiplier:0.444,loss:2.381484031677246,entropy:2.0733883380889893,explained_var_old:0.578,explained_var_new:0.652
# batch i:459, episode_len:9
# kl:0.02254,lr_multiplier:0.444,loss:2.4320998191833496,entropy:2.041527271270752,explained_var_old:0.496,explained_var_new:0.603
# batch i:460, episode_len:9
# kl:0.02257,lr_multiplier:0.444,loss:2.531826972961426,entropy:2.135866165161133,explained_var_old:0.530,explained_var_new:0.628
# batch i:461, episode_len:13
# kl:0.01896,lr_multiplier:0.444,loss:2.4187541007995605,entropy:2.128518581390381,explained_var_old:0.573,explained_var_new:0.640
# batch i:462, episode_len:9
# kl:0.02786,lr_multiplier:0.444,loss:2.518162250518799,entropy:2.1002719402313232,explained_var_old:0.487,explained_var_new:0.600
# batch i:463, episode_len:22
# kl:0.01870,lr_multiplier:0.444,loss:2.3623573780059814,entropy:1.9384775161743164,explained_var_old:0.520,explained_var_new:0.601
# batch i:464, episode_len:7
# kl:0.03271,lr_multiplier:0.444,loss:2.276401996612549,entropy:2.0276241302490234,explained_var_old:0.587,explained_var_new:0.685
# batch i:465, episode_len:13
# kl:0.02440,lr_multiplier:0.444,loss:2.4783358573913574,entropy:2.0238637924194336,explained_var_old:0.539,explained_var_new:0.601
# batch i:466, episode_len:11
# kl:0.02891,lr_multiplier:0.444,loss:2.4187850952148438,entropy:2.173041820526123,explained_var_old:0.641,explained_var_new:0.738
# batch i:467, episode_len:8
# kl:0.02306,lr_multiplier:0.444,loss:2.458965301513672,entropy:2.141000270843506,explained_var_old:0.578,explained_var_new:0.657
# batch i:468, episode_len:17
# kl:0.03343,lr_multiplier:0.444,loss:2.3759891986846924,entropy:1.9515211582183838,explained_var_old:0.532,explained_var_new:0.627
# batch i:469, episode_len:10
# kl:0.02789,lr_multiplier:0.444,loss:2.3733019828796387,entropy:2.0896315574645996,explained_var_old:0.598,explained_var_new:0.677
# batch i:470, episode_len:11
# kl:0.03648,lr_multiplier:0.444,loss:2.3172707557678223,entropy:1.9713764190673828,explained_var_old:0.555,explained_var_new:0.650
# batch i:471, episode_len:23
# kl:0.02649,lr_multiplier:0.444,loss:2.4156930446624756,entropy:2.0292773246765137,explained_var_old:0.527,explained_var_new:0.631
# batch i:472, episode_len:12
# kl:0.03046,lr_multiplier:0.444,loss:2.4763786792755127,entropy:2.0184881687164307,explained_var_old:0.443,explained_var_new:0.551
# batch i:473, episode_len:11
# kl:0.01564,lr_multiplier:0.444,loss:2.349874258041382,entropy:2.056079626083374,explained_var_old:0.583,explained_var_new:0.674
# batch i:474, episode_len:7
# kl:0.01982,lr_multiplier:0.444,loss:2.4140679836273193,entropy:2.020801067352295,explained_var_old:0.557,explained_var_new:0.631
# batch i:475, episode_len:9
# kl:0.02399,lr_multiplier:0.444,loss:2.5137743949890137,entropy:2.037578821182251,explained_var_old:0.391,explained_var_new:0.525
# batch i:476, episode_len:9
# kl:0.02366,lr_multiplier:0.444,loss:2.315424919128418,entropy:1.9650179147720337,explained_var_old:0.528,explained_var_new:0.616
# batch i:477, episode_len:18
# kl:0.01919,lr_multiplier:0.444,loss:2.382410764694214,entropy:1.9858969449996948,explained_var_old:0.536,explained_var_new:0.620
# batch i:478, episode_len:20
# kl:0.02646,lr_multiplier:0.444,loss:2.5070366859436035,entropy:2.164743661880493,explained_var_old:0.571,explained_var_new:0.664
# batch i:479, episode_len:9
# kl:0.02846,lr_multiplier:0.444,loss:2.4561750888824463,entropy:2.0851333141326904,explained_var_old:0.532,explained_var_new:0.613
# batch i:480, episode_len:7
# kl:0.01352,lr_multiplier:0.444,loss:2.4562036991119385,entropy:2.0623371601104736,explained_var_old:0.517,explained_var_new:0.609
# batch i:481, episode_len:7
# kl:0.02314,lr_multiplier:0.444,loss:2.3331427574157715,entropy:2.027914524078369,explained_var_old:0.590,explained_var_new:0.667
# batch i:482, episode_len:7
# kl:0.01968,lr_multiplier:0.444,loss:2.3684208393096924,entropy:2.0326290130615234,explained_var_old:0.589,explained_var_new:0.677
# batch i:483, episode_len:9
# kl:0.02009,lr_multiplier:0.444,loss:2.3545172214508057,entropy:2.0181219577789307,explained_var_old:0.558,explained_var_new:0.646
# batch i:484, episode_len:8
# kl:0.02686,lr_multiplier:0.444,loss:2.3345420360565186,entropy:2.007934093475342,explained_var_old:0.562,explained_var_new:0.648
# batch i:485, episode_len:7
# kl:0.02264,lr_multiplier:0.444,loss:2.366154432296753,entropy:2.0246331691741943,explained_var_old:0.604,explained_var_new:0.666
# batch i:486, episode_len:13
# kl:0.01707,lr_multiplier:0.444,loss:2.4483282566070557,entropy:2.0687224864959717,explained_var_old:0.513,explained_var_new:0.598
# batch i:487, episode_len:8
# kl:0.02887,lr_multiplier:0.444,loss:2.4349586963653564,entropy:2.019338607788086,explained_var_old:0.518,explained_var_new:0.605
# batch i:488, episode_len:7
# kl:0.03973,lr_multiplier:0.444,loss:2.4185585975646973,entropy:2.0371599197387695,explained_var_old:0.512,explained_var_new:0.609
# batch i:489, episode_len:13
# kl:0.02622,lr_multiplier:0.444,loss:2.4710891246795654,entropy:2.111849308013916,explained_var_old:0.526,explained_var_new:0.612
# batch i:490, episode_len:7
# kl:0.02026,lr_multiplier:0.444,loss:2.4435386657714844,entropy:2.019421100616455,explained_var_old:0.524,explained_var_new:0.629
# batch i:491, episode_len:7
# kl:0.03139,lr_multiplier:0.444,loss:2.296710729598999,entropy:1.9599833488464355,explained_var_old:0.558,explained_var_new:0.648
# batch i:492, episode_len:7
# kl:0.01887,lr_multiplier:0.444,loss:2.4003796577453613,entropy:2.0097503662109375,explained_var_old:0.522,explained_var_new:0.609
# batch i:493, episode_len:9
# kl:0.02613,lr_multiplier:0.444,loss:2.313898801803589,entropy:2.060924768447876,explained_var_old:0.619,explained_var_new:0.688
# batch i:494, episode_len:9
# kl:0.02277,lr_multiplier:0.444,loss:2.3203887939453125,entropy:2.006319999694824,explained_var_old:0.624,explained_var_new:0.704
# batch i:495, episode_len:13
# kl:0.02329,lr_multiplier:0.444,loss:2.4552931785583496,entropy:2.0089166164398193,explained_var_old:0.519,explained_var_new:0.613
# batch i:496, episode_len:7
# kl:0.01984,lr_multiplier:0.444,loss:2.4388928413391113,entropy:2.082029342651367,explained_var_old:0.519,explained_var_new:0.601
# batch i:497, episode_len:7
# kl:0.02331,lr_multiplier:0.444,loss:2.327486038208008,entropy:2.0431883335113525,explained_var_old:0.615,explained_var_new:0.699
# batch i:498, episode_len:7
# kl:0.02321,lr_multiplier:0.444,loss:2.323507785797119,entropy:1.9255261421203613,explained_var_old:0.583,explained_var_new:0.658
# batch i:499, episode_len:7
# kl:0.01852,lr_multiplier:0.444,loss:2.4055941104888916,entropy:2.1392276287078857,explained_var_old:0.609,explained_var_new:0.673
# batch i:500, episode_len:8
# kl:0.02772,lr_multiplier:0.444,loss:2.3358633518218994,entropy:2.03106689453125,explained_var_old:0.648,explained_var_new:0.714
# current self-play batch: 500
# num_playouts:3000, win: 4, lose: 6, tie:0
# 发现新的最优策略，进行策略更新
