# %% [markdown]
# # 母婴用品会员留存分析

# %% [markdown]
# ## 思维导图

# %% [markdown]
# <div><img src="attachment:image.png" width="3000"/></div>

# %% [markdown]
# ## Tableau仪表盘截图

# %% [markdown]
# <div><img src="attachment:image.png" width="1000"/></div>
