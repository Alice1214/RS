# %% [markdown]
# # 银行产品推荐

# %% [markdown]
# * Content：桑坦德银行产品推荐,使用xgboost/catboost预测2016年6月用户会购买的新产品,评估指标为MAP@7
# * Author:  HuiHui
# * Date:    2020-04-23
# * Reference:https://www.kaggle.com/c/santander-product-recommendation/data
# * 数据集：桑坦德银行2015.1.28-2016.5.28的客户行为数据
#     * ncodpers: 客户代码

# %%
from google.colab import drive
drive.mount('/content/gdrive') #挂载网盘
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir("/content/gdrive/My Drive/RS/Santander Product Recommendation") #改变当前工作目录到指定的路径

# %% [markdown]
# ## 安装依赖包

# %%
# !pip install -q tqdm
# !pip install -q xgboost

# %% [markdown]
# ## 导入需要的库

# %%
import gc
from tqdm import tqdm
import numpy as np
import pandas as pd
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %% [markdown]
# ## 获取数据

# %%
# 加载全量样本
train = pd.read_csv('./santander-product-recommendation/train_ver2.csv',dtype = {'age': 'str', 'antiguedad': 'str','renta': 'str'})
test = pd.read_csv('./santander-product-recommendation/test_ver2.csv',dtype = {'age': 'str', 'antiguedad': 'str','renta': 'str'})

# # 加载小样本
# train = pd.read_csv('./santander-product-recommendation-small/train.csv',dtype = {'age': 'str', 'antiguedad': 'str','renta': 'str'})
# test = pd.read_csv('./santander-product-recommendation-small/test.csv',dtype = {'age': 'str', 'antiguedad': 'str','renta': 'str')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (11,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ##数据清洗

# %%
# test、train数据拼接
train['origin'] = 'train'
test['origin'] = 'test'
matrix = pd.concat([train,test], ignore_index=True, sort=False) 

del train, test
gc.collect() #清理内存

# 数据初探
# matrix.head()
# matrix.info()
# pd.set_option('display.max_columns', None) # 强制输出所有属性值
# print(matrix.describe(include='all'))

# （1）特征初筛
# 初步筛选出相关性高的特征列
mapping_dict = {
'sexo'          : {'nan':0,'H':0, 'V':1},
'ind_actividad_cliente' : {'nan':0, '0.0':0, '0':0,'1.0':1, '1':1},
'segmento'      : {'nan':0, '01 - TOP':0, '03 - UNIVERSITARIO':1, '02 - PARTICULARES':2},
'ind_nuevo'     : {'nan':0, '1.0':0, '1':0,  '0.0':1, '0':1 },
'tiprel_1mes'   : {'nan':0, 'P':0, 'R':0, 'N':0, 'I':1, 'A':2},
'indext'        : {'nan':0, 'S':0, 'N':1}
} # 分类特征值转换

target_raw_cols = ['ind_ahor_fin_ult1', 'ind_aval_fin_ult1', 'ind_cco_fin_ult1',  'ind_cder_fin_ult1',
                   'ind_cno_fin_ult1',  'ind_ctju_fin_ult1', 'ind_ctma_fin_ult1', 'ind_ctop_fin_ult1',
                   'ind_ctpp_fin_ult1', 'ind_deco_fin_ult1', 'ind_deme_fin_ult1', 'ind_dela_fin_ult1',
                   'ind_ecue_fin_ult1', 'ind_fond_fin_ult1', 'ind_hip_fin_ult1',  'ind_plan_fin_ult1',
                   'ind_pres_fin_ult1', 'ind_reca_fin_ult1', 'ind_tjcr_fin_ult1', 'ind_valo_fin_ult1',
                   'ind_viv_fin_ult1',  'ind_nomina_ult1',   'ind_nom_pens_ult1', 'ind_recibo_ult1']

target_cols = target_raw_cols[2:] # 储蓄账户及担保不算target？？？
con_cols = ['ncodpers', 'fecha_dato', 'age', 'antiguedad','renta']
cat_cols = list(mapping_dict.keys())
user_cols = con_cols + cat_cols + target_raw_cols +["origin"] # 通用特征列+分类特征列+目标列
print(user_cols)
matrix=matrix[user_cols]

# （2）处理缺失值
# 随机抽取数据集中的10条数据观察
# np.random.seed(0) 
# train.sample(10) 
# 统计缺失值的数量
missing_values_count = matrix.isnull().sum() 
# print(missing_values_count)
# 缺失值的数目占总数的百分比
total_cells = np.product(matrix.shape)
total_missing = missing_values_count.sum()
print((total_missing/total_cells) * 100)
# 分析出现缺失值的原因:没有被记录or根本不存在？--> 剔除缺失值/补全缺失值
# 中位数补充renta
# matrix["renta"].fillna(matrix["renta"].median(),inplace=True)
# 其余缺失值在格式化时补全

# （3）数据格式化
matrix['fecha_dato'] = pd.to_datetime(matrix['fecha_dato'],format = "%Y/%m/%d",errors='coerce') # r日期转换错误的会设置为NaN,可后期手动转换
# print(matrix['fecha_dato'].loc[matrix['fecha_dato'].isnull()]) #查看是否有没有成功转换的日期

def getAge(str_age):
  age = str_age.strip()
  if age == 'NA' or age == 'nan':
    age1 = 2
  elif float(age) < 20:
    age1 = 0
  elif float(age) < 30:
    age1 = 1
  elif float(age) < 40:
    age1 = 2
  elif float(age) < 50:
    age1 = 3
  elif float(age) < 60:
    age1 = 4
  else:
    age1 =  5
  return age1
matrix['age'] = matrix['age'].apply(lambda x: getAge(x))

def getCustSeniority(str_seniority):
  cust_seniority = str_seniority.strip()
  if cust_seniority == 'NA' or cust_seniority == 'nan':
    seniority = 4
  elif float(cust_seniority) < 50:
    seniority = 0
  elif float(cust_seniority) < 75:
    seniority = 1
  elif float(cust_seniority) < 100:
    seniority = 2
  elif float(cust_seniority) < 125:
    seniority = 3
  elif float(cust_seniority) < 150:
    seniority = 4
  elif float(cust_seniority) < 175:
    seniority = 5
  elif float(cust_seniority) < 200:
    seniority = 6
  elif float(cust_seniority) < 225:
    seniority = 7
  else:
    seniority = 8
  return seniority
matrix['antiguedad'] = matrix['antiguedad'].apply(lambda x: getCustSeniority(x))

def getRent(rent):
  rent=str(rent)
  rent = rent.strip() # 把字符串(str)的头和尾的空格，以及位于头尾的\n \t之类给删掉
  if rent == 'NA' or rent == 'nan':
    rent1 = 4
  elif float(rent) < 45542.97:
    rent1 = 1
  elif float(rent) < 57629.67:
    rent1 = 2
  elif float(rent) < 68211.78:
    rent1 = 3
  elif float(rent) < 78852.39:
    rent1 = 4
  elif float(rent) < 90461.97:
    rent1 = 5
  elif float(rent) < 103855.23:
    rent1 = 6
  elif float(rent) < 120063.00:
    rent1 = 7
  elif float(rent) < 141347.49:
    rent1 = 8
  elif float(rent) < 173418.12:
    rent1 = 9
  elif float(rent) < 234687.12:
    rent1 = 10
  else:
    rent1 = 11
  return rent1
matrix['renta'] = matrix['renta'].apply(lambda x: getRent(x))

for col in cat_cols:
  matrix[col] = matrix[col].apply(lambda x: mapping_dict[col][str(x)])

for col in  target_raw_cols:
  matrix[col].fillna(0, inplace=True)
matrix.info()
# Out:
# ['ncodpers', 'fecha_dato', 'age', 'antiguedad', 'renta', 'sexo', 'ind_actividad_cliente', 'segmento', 'ind_nuevo', 'tiprel_1mes', 'indext', 'ind_ahor_fin_ult1', 'ind_aval_fin_ult1', 'ind_cco_fin_ult1', 'ind_cder_fin_ult1', 'ind_cno_fin_ult1', 'ind_ctju_fin_ult1', 'ind_ctma_fin_ult1', 'ind_ctop_fin_ult1', 'ind_ctpp_fin_ult1', 'ind_deco_fin_ult1', 'ind_deme_fin_ult1', 'ind_dela_fin_ult1', 'ind_ecue_fin_ult1', 'ind_fond_fin_ult1', 'ind_hip_fin_ult1', 'ind_plan_fin_ult1', 'ind_pres_fin_ult1', 'ind_reca_fin_ult1', 'ind_tjcr_fin_ult1', 'ind_valo_fin_ult1', 'ind_viv_fin_ult1', 'ind_nomina_ult1', 'ind_nom_pens_ult1', 'ind_recibo_ult1', 'origin']
# 4.876370198388753
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14576924 entries, 0 to 14576923
# Data columns (total 36 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ncodpers               int64
#  1   fecha_dato             datetime64[ns]
#  2   age                    int64
#  3   antiguedad             int64
#  4   renta                  int64
#  5   sexo                   int64
#  6   ind_actividad_cliente  int64
#  7   segmento               int64
#  8   ind_nuevo              int64
#  9   tiprel_1mes            int64
#  10  indext                 int64
#  11  ind_ahor_fin_ult1      float64
#  12  ind_aval_fin_ult1      float64
#  13  ind_cco_fin_ult1       float64
#  14  ind_cder_fin_ult1      float64
#  15  ind_cno_fin_ult1       float64
#  16  ind_ctju_fin_ult1      float64
#  17  ind_ctma_fin_ult1      float64
#  18  ind_ctop_fin_ult1      float64
#  19  ind_ctpp_fin_ult1      float64
#  20  ind_deco_fin_ult1      float64
#  21  ind_deme_fin_ult1      float64
#  22  ind_dela_fin_ult1      float64
#  23  ind_ecue_fin_ult1      float64
#  24  ind_fond_fin_ult1      float64
#  25  ind_hip_fin_ult1       float64
#  26  ind_plan_fin_ult1      float64
#  27  ind_pres_fin_ult1      float64
#  28  ind_reca_fin_ult1      float64
#  29  ind_tjcr_fin_ult1      float64
#  30  ind_valo_fin_ult1      float64
#  31  ind_viv_fin_ult1       float64
#  32  ind_nomina_ult1        float64
#  33  ind_nom_pens_ult1      float64
#  34  ind_recibo_ult1        float64
#  35  origin                 object
# dtypes: datetime64[ns](1), float64(24), int64(10), object(1)
# memory usage: 3.9+ GB

# %% [markdown]
# ## 数据探索（可视化）

# %%
# 样本数据是否均衡

# %% [markdown]
# ## 特征工程
# * 特征构建、特征生成、特征选择

# %%
# 特征构建：用2015年1-5月产品购买记录和6月公共特征作为训练数据X_train，2015年6月作为y_train_sets(24个目标列);用2016年1-5月产品购买记录和6月公共特征作为测试数据X_test,预测2016年6月购买产品情况
'''
后续可考虑构建这些特征
ind_(xyz)_ult1_last：产品的最后一个月指数（滞后1）
ind_(xyz)_ult1_00：索引从0到0到上个月的过渡次数
ind_(xyz)_ult1_01：索引从0到1到上个月的过渡次数
ind_(xyz)_ult1_10：索引从1到0到上个月的过渡次数
ind_(xyz)_ult1_11：索引从1到1到上个月的过渡次数
ind_(xyz)_ult1_0len：直到上个月的连续0索引的长度
products_last：产品上月指数的串联
n_products_last：上个月购买的产品数量
'''

# 处理训练数据及测试数据
# 返回X_TRAIN,y_train_sets,X_test
def process_data(matrix): 
  # 全量样本时
  train_date_list=['2015-06-28', '2015-05-28', '2015-04-28','2015-03-28', '2015-02-28', '2015-01-28']
  test_date_list=['2016-06-28','2016-05-28', '2016-04-28', '2016-03-28', '2016-02-28', '2016-01-28']

  # # 小样本时（小样本中训练数据到2016年4月，测试数据为2016年5月，因此稍作修改，最终预测的结果为2016年5月购买新产品情况）
  # train_date_list=['2015-05-28', '2015-04-28','2015-03-28', '2015-02-28', '2015-01-28']
  # test_date_list=['2016-05-28', '2016-04-28', '2016-03-28', '2016-02-28', '2016-01-28']

  train_data = matrix[matrix['origin'] == 'train'].drop(['origin'], axis=1)
  test_data = matrix[matrix['origin'] == 'test'].drop(target_raw_cols+['origin'], axis=1)

  # 处理训练数据
  this_month = train_data[train_data['fecha_dato'].isin([train_date_list[0]])] #选取2015-06月（当月）数据
  hist_data = train_data.loc[:,['ncodpers','fecha_dato'] + target_raw_cols] #产品历史购买记录

  # 加入产品历史购买记录数据
  for i in range(1, len(train_date_list)):
    pre_month = hist_data[hist_data['fecha_dato'].isin([train_date_list[i]])].loc[:,['ncodpers'] + target_raw_cols] # 上个月产品购买记录
    pre_month = pre_month.add_prefix(str(i) + "_") # 对上个月产品购买记录加前缀
    pre_month.rename(columns={str(i) + '_ncodpers': 'ncodpers'}, inplace=True) # 去掉'ncodpers'刚加的前缀，以便之后合并数据
    this_month = pd.merge(this_month, pre_month, on=['ncodpers'], how='left') #当月数据+上个月产品购买记录
  this_month.fillna(0, inplace=True)

  X_TRAIN=this_month.drop(target_raw_cols+["fecha_dato"], axis=1)
  y_train_sets=this_month[target_raw_cols] # 24个目标列，分别用XGBoost预测购买概率

  # 处理测试数据
  this_month_t = test_data[test_data['fecha_dato'].isin([test_date_list[0]])] #选取2016-06月数据
  # this_month_t = test_data
  for i in range(1, len(test_date_list)):
    pre_month_t = hist_data[hist_data['fecha_dato'].isin([test_date_list[i]])].loc[:,['ncodpers'] + target_raw_cols] # 上个月产品购买记录
    pre_month_t = pre_month_t.add_prefix(str(i) + "_") # 对上个月产品购买记录加前缀
    pre_month_t.rename(columns={str(i) + '_ncodpers': 'ncodpers'}, inplace=True) # 去掉'ncodpers'刚加的前缀，以便之后合并数据
    this_month_t = pd.merge(this_month_t, pre_month_t, on=['ncodpers'], how='left') #当月数据+上个月产品购买记录
  this_month_t.fillna(0, inplace=True)

  X_test=this_month_t.drop(["fecha_dato"], axis=1)

  # 清理内存
  del matrix,train_data,test_data,this_month,hist_data,pre_month,this_month_t,pre_month_t
  gc.collect()

  return X_TRAIN,y_train_sets,X_test

X_TRAIN,y_train_sets,X_test = process_data(matrix)

# 保存特征文件，调试不同算法模型
X_TRAIN.to_csv('./X_TRAIN.csv', index=False)
y_train_sets.to_csv('./y_train_sets.csv', index=False)
X_test.to_csv('./X_test.csv', index=False)

print("ok")
# Out:
# ok

# %% [markdown]
# ## 使用XGBoost模型

# %%
target_raw_cols = ['ind_ahor_fin_ult1', 'ind_aval_fin_ult1', 'ind_cco_fin_ult1',  'ind_cder_fin_ult1',
                   'ind_cno_fin_ult1',  'ind_ctju_fin_ult1', 'ind_ctma_fin_ult1', 'ind_ctop_fin_ult1',
                   'ind_ctpp_fin_ult1', 'ind_deco_fin_ult1', 'ind_deme_fin_ult1', 'ind_dela_fin_ult1',
                   'ind_ecue_fin_ult1', 'ind_fond_fin_ult1', 'ind_hip_fin_ult1',  'ind_plan_fin_ult1',
                   'ind_pres_fin_ult1', 'ind_reca_fin_ult1', 'ind_tjcr_fin_ult1', 'ind_valo_fin_ult1',
                   'ind_viv_fin_ult1',  'ind_nomina_ult1',   'ind_nom_pens_ult1', 'ind_recibo_ult1']
# 读取保存的特征文件
X_TRAIN=pd.read_csv('./X_TRAIN.csv')
y_train_sets=pd.read_csv('./y_train_sets.csv')
X_test=pd.read_csv('./X_test.csv')

# 分别用XGBoost预测24个产品的购买概率
def runXGB(X_train, X_valid, y_train, y_valid,X_test,seed_val=42):
  model = xgb.XGBClassifier(
      max_depth=8,
      n_estimators=1000,
      min_child_weight=300, 
      colsample_bytree=0.8, 
      subsample=0.8, 
      eta=0.35, #学习率调小，训练误差减小，泛化误差增大   
      seed=seed_val #每次产生的随机数一样；这里设置随机数种子是因为训练过程中采用了随机采样、随机属性选择
      )
  model.fit(
      X_train, y_train,
      eval_metric='logloss', eval_set=[(X_train, y_train), (X_valid, y_valid)],
      verbose=True,
      #早停法，如果eval_metric在10epoch没有进步就stop
      early_stopping_rounds=10
      )
  prob = pd.Series(model.predict_proba(X_test)[:,1]) #购买该产品的概率预测
  return prob

result=X_test[["ncodpers"]]
for y in tqdm(target_raw_cols): # 进度条
  # 将训练集进行切分，20%用于验证
  print(y)
  X_train, X_valid, y_train, y_valid = train_test_split(X_TRAIN, y_train_sets[y], test_size=0.2)
  result[y]=runXGB(X_train, X_valid, y_train, y_valid, X_test)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# ind_ahor_fin_ult1
# [0]	validation_0-logloss:0.598188	validation_1-logloss:0.598189
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.520422	validation_1-logloss:0.520423
# [2]	validation_0-logloss:0.455571	validation_1-logloss:0.455573
# [3]	validation_0-logloss:0.400756	validation_1-logloss:0.400759
# [4]	validation_0-logloss:0.353934	validation_1-logloss:0.353937
# [5]	validation_0-logloss:0.313599	validation_1-logloss:0.313603
# [6]	validation_0-logloss:0.278618	validation_1-logloss:0.278622
# [7]	validation_0-logloss:0.248109	validation_1-logloss:0.248114
# [8]	validation_0-logloss:0.221376	validation_1-logloss:0.221382
# [9]	validation_0-logloss:0.197856	validation_1-logloss:0.197862
# [10]	validation_0-logloss:0.177096	validation_1-logloss:0.177103
# [11]	validation_0-logloss:0.158719	validation_1-logloss:0.158726
# [12]	validation_0-logloss:0.14241	validation_1-logloss:0.142417
# [13]	validation_0-logloss:0.127905	validation_1-logloss:0.127913
# [14]	validation_0-logloss:0.114979	validation_1-logloss:0.114988
# [15]	validation_0-logloss:0.103445	validation_1-logloss:0.103454
# [16]	validation_0-logloss:0.093134	validation_1-logloss:0.093143
# [17]	validation_0-logloss:0.083905	validation_1-logloss:0.083914
# [18]	validation_0-logloss:0.075637	validation_1-logloss:0.075647
# [19]	validation_0-logloss:0.068221	validation_1-logloss:0.068232
# [20]	validation_0-logloss:0.061566	validation_1-logloss:0.061577
# [21]	validation_0-logloss:0.055586	validation_1-logloss:0.055597
# [22]	validation_0-logloss:0.050211	validation_1-logloss:0.050223
# [23]	validation_0-logloss:0.045375	validation_1-logloss:0.045387
# [24]	validation_0-logloss:0.041024	validation_1-logloss:0.041036
# [25]	validation_0-logloss:0.037107	validation_1-logloss:0.03712
# [26]	validation_0-logloss:0.033578	validation_1-logloss:0.033592
# [27]	validation_0-logloss:0.030399	validation_1-logloss:0.030412
# [28]	validation_0-logloss:0.027531	validation_1-logloss:0.027546
# [29]	validation_0-logloss:0.024946	validation_1-logloss:0.024961
# [30]	validation_0-logloss:0.022614	validation_1-logloss:0.022629
# [31]	validation_0-logloss:0.020511	validation_1-logloss:0.020526
# [32]	validation_0-logloss:0.018613	validation_1-logloss:0.018629
# [33]	validation_0-logloss:0.016901	validation_1-logloss:0.016918
# [34]	validation_0-logloss:0.015356	validation_1-logloss:0.015373
# [35]	validation_0-logloss:0.013961	validation_1-logloss:0.013978
# [36]	validation_0-logloss:0.012703	validation_1-logloss:0.012721
# [37]	validation_0-logloss:0.011568	validation_1-logloss:0.011586
# [38]	validation_0-logloss:0.010543	validation_1-logloss:0.010562
# [39]	validation_0-logloss:0.009617	validation_1-logloss:0.009636
# [40]	validation_0-logloss:0.008781	validation_1-logloss:0.008801
# [41]	validation_0-logloss:0.008027	validation_1-logloss:0.008048
# [42]	validation_0-logloss:0.007347	validation_1-logloss:0.007368
# [43]	validation_0-logloss:0.006732	validation_1-logloss:0.006754
# [44]	validation_0-logloss:0.006177	validation_1-logloss:0.0062
# [45]	validation_0-logloss:0.005678	validation_1-logloss:0.005701
# [46]	validation_0-logloss:0.005227	validation_1-logloss:0.00525
# [47]	validation_0-logloss:0.004819	validation_1-logloss:0.004843
# [48]	validation_0-logloss:0.004452	validation_1-logloss:0.004476
# [49]	validation_0-logloss:0.004121	validation_1-logloss:0.004146
# [50]	validation_0-logloss:0.003822	validation_1-logloss:0.003847
# [51]	validation_0-logloss:0.003553	validation_1-logloss:0.003579
# [52]	validation_0-logloss:0.00331	validation_1-logloss:0.003336
# [53]	validation_0-logloss:0.003091	validation_1-logloss:0.003119
# [54]	validation_0-logloss:0.002895	validation_1-logloss:0.002923
# [55]	validation_0-logloss:0.002718	validation_1-logloss:0.002747
# [56]	validation_0-logloss:0.00256	validation_1-logloss:0.002589
# [57]	validation_0-logloss:0.002417	validation_1-logloss:0.002447
# [58]	validation_0-logloss:0.002289	validation_1-logloss:0.002319
# [59]	validation_0-logloss:0.002173	validation_1-logloss:0.002204
# [60]	validation_0-logloss:0.00207	validation_1-logloss:0.002101
# [61]	validation_0-logloss:0.001979	validation_1-logloss:0.00201
# [62]	validation_0-logloss:0.001897	validation_1-logloss:0.001928
# [63]	validation_0-logloss:0.001824	validation_1-logloss:0.001856
# [64]	validation_0-logloss:0.001759	validation_1-logloss:0.001791
# [65]	validation_0-logloss:0.001701	validation_1-logloss:0.001733
# [66]	validation_0-logloss:0.001649	validation_1-logloss:0.001681
# [67]	validation_0-logloss:0.001603	validation_1-logloss:0.001635
# [68]	validation_0-logloss:0.001562	validation_1-logloss:0.001595
# [69]	validation_0-logloss:0.001526	validation_1-logloss:0.001559
# [70]	validation_0-logloss:0.001494	validation_1-logloss:0.001527
# [71]	validation_0-logloss:0.001466	validation_1-logloss:0.0015
# [72]	validation_0-logloss:0.001441	validation_1-logloss:0.001475
# [73]	validation_0-logloss:0.00142	validation_1-logloss:0.001454
# [74]	validation_0-logloss:0.001401	validation_1-logloss:0.001435
# [75]	validation_0-logloss:0.001383	validation_1-logloss:0.001418
# [76]	validation_0-logloss:0.00137	validation_1-logloss:0.001405
# [77]	validation_0-logloss:0.001356	validation_1-logloss:0.001392
# [78]	validation_0-logloss:0.001346	validation_1-logloss:0.001382
# [79]	validation_0-logloss:0.001337	validation_1-logloss:0.001373
# [80]	validation_0-logloss:0.001329	validation_1-logloss:0.001365
# [81]	validation_0-logloss:0.001322	validation_1-logloss:0.001358
# [82]	validation_0-logloss:0.001315	validation_1-logloss:0.001352
# [83]	validation_0-logloss:0.00131	validation_1-logloss:0.001347
# [84]	validation_0-logloss:0.001305	validation_1-logloss:0.001342
# [85]	validation_0-logloss:0.001302	validation_1-logloss:0.001339
# [86]	validation_0-logloss:0.001299	validation_1-logloss:0.001336
# [87]	validation_0-logloss:0.001296	validation_1-logloss:0.001333
# [88]	validation_0-logloss:0.001294	validation_1-logloss:0.001331
# [89]	validation_0-logloss:0.001292	validation_1-logloss:0.001329
# [90]	validation_0-logloss:0.00129	validation_1-logloss:0.001328
# [91]	validation_0-logloss:0.001289	validation_1-logloss:0.001326
# [92]	validation_0-logloss:0.001287	validation_1-logloss:0.001325
# [93]	validation_0-logloss:0.001286	validation_1-logloss:0.001324
# [94]	validation_0-logloss:0.001285	validation_1-logloss:0.001323
# [95]	validation_0-logloss:0.001285	validation_1-logloss:0.001323
# [96]	validation_0-logloss:0.001284	validation_1-logloss:0.001322
# [97]	validation_0-logloss:0.001284	validation_1-logloss:0.001322
# [98]	validation_0-logloss:0.001283	validation_1-logloss:0.001322
# [99]	validation_0-logloss:0.001283	validation_1-logloss:0.001321
# [100]	validation_0-logloss:0.001283	validation_1-logloss:0.001321
# [101]	validation_0-logloss:0.001283	validation_1-logloss:0.001321
# [102]	validation_0-logloss:0.001283	validation_1-logloss:0.001321
# [103]	validation_0-logloss:0.001282	validation_1-logloss:0.001321
# [104]	validation_0-logloss:0.001282	validation_1-logloss:0.001321
# [105]	validation_0-logloss:0.001282	validation_1-logloss:0.001321
# [106]	validation_0-logloss:0.001282	validation_1-logloss:0.001321
# [107]	validation_0-logloss:0.001282	validation_1-logloss:0.001321
# [108]	validation_0-logloss:0.001282	validation_1-logloss:0.001321
# [109]	validation_0-logloss:0.001282	validation_1-logloss:0.001321
# Stopping. Best iteration:
# [99]	validation_0-logloss:0.001283	validation_1-logloss:0.001321
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   4%|▍         | 1/24 [01:50<42:20, 110.45s/it]
# ind_aval_fin_ult1
# [0]	validation_0-logloss:0.598151	validation_1-logloss:0.598155
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.520352	validation_1-logloss:0.520359
# [2]	validation_0-logloss:0.455476	validation_1-logloss:0.455486
# [3]	validation_0-logloss:0.400638	validation_1-logloss:0.400651
# [4]	validation_0-logloss:0.353793	validation_1-logloss:0.353808
# [5]	validation_0-logloss:0.31344	validation_1-logloss:0.313458
# [6]	validation_0-logloss:0.278441	validation_1-logloss:0.278462
# [7]	validation_0-logloss:0.247915	validation_1-logloss:0.247938
# [8]	validation_0-logloss:0.221165	validation_1-logloss:0.22119
# [9]	validation_0-logloss:0.197632	validation_1-logloss:0.197659
# [10]	validation_0-logloss:0.176857	validation_1-logloss:0.176887
# [11]	validation_0-logloss:0.158465	validation_1-logloss:0.158496
# [12]	validation_0-logloss:0.142141	validation_1-logloss:0.142174
# [13]	validation_0-logloss:0.127622	validation_1-logloss:0.127657
# [14]	validation_0-logloss:0.114684	validation_1-logloss:0.114722
# [15]	validation_0-logloss:0.103137	validation_1-logloss:0.103176
# [16]	validation_0-logloss:0.092813	validation_1-logloss:0.092855
# [17]	validation_0-logloss:0.083573	validation_1-logloss:0.083616
# [18]	validation_0-logloss:0.075293	validation_1-logloss:0.075339
# [19]	validation_0-logloss:0.067866	validation_1-logloss:0.067913
# [20]	validation_0-logloss:0.061198	validation_1-logloss:0.061247
# [21]	validation_0-logloss:0.055208	validation_1-logloss:0.055259
# [22]	validation_0-logloss:0.049821	validation_1-logloss:0.049874
# [23]	validation_0-logloss:0.044976	validation_1-logloss:0.045031
# [24]	validation_0-logloss:0.040614	validation_1-logloss:0.04067
# [25]	validation_0-logloss:0.036685	validation_1-logloss:0.036744
# [26]	validation_0-logloss:0.033145	validation_1-logloss:0.033206
# [27]	validation_0-logloss:0.029954	validation_1-logloss:0.030016
# [28]	validation_0-logloss:0.027077	validation_1-logloss:0.027141
# [29]	validation_0-logloss:0.024481	validation_1-logloss:0.024547
# [30]	validation_0-logloss:0.02214	validation_1-logloss:0.022207
# [31]	validation_0-logloss:0.020027	validation_1-logloss:0.020097
# [32]	validation_0-logloss:0.01812	validation_1-logloss:0.018191
# [33]	validation_0-logloss:0.016398	validation_1-logloss:0.016471
# [34]	validation_0-logloss:0.014842	validation_1-logloss:0.014917
# [35]	validation_0-logloss:0.013437	validation_1-logloss:0.013514
# [36]	validation_0-logloss:0.012168	validation_1-logloss:0.012247
# [37]	validation_0-logloss:0.011022	validation_1-logloss:0.011103
# [38]	validation_0-logloss:0.009987	validation_1-logloss:0.010069
# [39]	validation_0-logloss:0.009051	validation_1-logloss:0.009135
# [40]	validation_0-logloss:0.008206	validation_1-logloss:0.008291
# [41]	validation_0-logloss:0.007441	validation_1-logloss:0.007529
# [42]	validation_0-logloss:0.00675	validation_1-logloss:0.00684
# [43]	validation_0-logloss:0.006126	validation_1-logloss:0.006217
# [44]	validation_0-logloss:0.005561	validation_1-logloss:0.005654
# [45]	validation_0-logloss:0.005051	validation_1-logloss:0.005146
# [46]	validation_0-logloss:0.004591	validation_1-logloss:0.004687
# [47]	validation_0-logloss:0.004174	validation_1-logloss:0.004273
# [48]	validation_0-logloss:0.003798	validation_1-logloss:0.003898
# [49]	validation_0-logloss:0.003458	validation_1-logloss:0.003559
# [50]	validation_0-logloss:0.003151	validation_1-logloss:0.003254
# [51]	validation_0-logloss:0.002873	validation_1-logloss:0.002978
# [52]	validation_0-logloss:0.002622	validation_1-logloss:0.002729
# [53]	validation_0-logloss:0.002395	validation_1-logloss:0.002504
# [54]	validation_0-logloss:0.00219	validation_1-logloss:0.0023
# [55]	validation_0-logloss:0.002004	validation_1-logloss:0.002116
# [56]	validation_0-logloss:0.001837	validation_1-logloss:0.001951
# [57]	validation_0-logloss:0.001685	validation_1-logloss:0.001801
# [58]	validation_0-logloss:0.001549	validation_1-logloss:0.001666
# [59]	validation_0-logloss:0.001426	validation_1-logloss:0.001545
# [60]	validation_0-logloss:0.001316	validation_1-logloss:0.001437
# [61]	validation_0-logloss:0.001215	validation_1-logloss:0.001338
# [62]	validation_0-logloss:0.001124	validation_1-logloss:0.001249
# [63]	validation_0-logloss:0.001043	validation_1-logloss:0.001169
# [64]	validation_0-logloss:0.000969	validation_1-logloss:0.001097
# [65]	validation_0-logloss:0.000903	validation_1-logloss:0.001033
# [66]	validation_0-logloss:0.000844	validation_1-logloss:0.000975
# [67]	validation_0-logloss:0.00079	validation_1-logloss:0.000923
# [68]	validation_0-logloss:0.000742	validation_1-logloss:0.000877
# [69]	validation_0-logloss:0.000699	validation_1-logloss:0.000835
# [70]	validation_0-logloss:0.00066	validation_1-logloss:0.000798
# [71]	validation_0-logloss:0.000624	validation_1-logloss:0.000764
# [72]	validation_0-logloss:0.000593	validation_1-logloss:0.000734
# [73]	validation_0-logloss:0.000565	validation_1-logloss:0.000707
# [74]	validation_0-logloss:0.000539	validation_1-logloss:0.000683
# [75]	validation_0-logloss:0.000516	validation_1-logloss:0.000662
# [76]	validation_0-logloss:0.000495	validation_1-logloss:0.000643
# [77]	validation_0-logloss:0.000477	validation_1-logloss:0.000626
# [78]	validation_0-logloss:0.00046	validation_1-logloss:0.000611
# [79]	validation_0-logloss:0.000446	validation_1-logloss:0.000598
# [80]	validation_0-logloss:0.000433	validation_1-logloss:0.000587
# [81]	validation_0-logloss:0.000422	validation_1-logloss:0.000577
# [82]	validation_0-logloss:0.000412	validation_1-logloss:0.000568
# [83]	validation_0-logloss:0.000402	validation_1-logloss:0.00056
# [84]	validation_0-logloss:0.000394	validation_1-logloss:0.000554
# [85]	validation_0-logloss:0.000387	validation_1-logloss:0.000548
# [86]	validation_0-logloss:0.000381	validation_1-logloss:0.000543
# [87]	validation_0-logloss:0.000375	validation_1-logloss:0.000539
# [88]	validation_0-logloss:0.00037	validation_1-logloss:0.000535
# [89]	validation_0-logloss:0.000366	validation_1-logloss:0.000532
# [90]	validation_0-logloss:0.000363	validation_1-logloss:0.00053
# [91]	validation_0-logloss:0.000359	validation_1-logloss:0.000527
# [92]	validation_0-logloss:0.000356	validation_1-logloss:0.000525
# [93]	validation_0-logloss:0.000354	validation_1-logloss:0.000524
# [94]	validation_0-logloss:0.000352	validation_1-logloss:0.000523
# [95]	validation_0-logloss:0.00035	validation_1-logloss:0.000522
# [96]	validation_0-logloss:0.000348	validation_1-logloss:0.000521
# [97]	validation_0-logloss:0.000346	validation_1-logloss:0.000521
# [98]	validation_0-logloss:0.000345	validation_1-logloss:0.00052
# [99]	validation_0-logloss:0.000344	validation_1-logloss:0.00052
# [100]	validation_0-logloss:0.000344	validation_1-logloss:0.00052
# [101]	validation_0-logloss:0.000343	validation_1-logloss:0.00052
# [102]	validation_0-logloss:0.000342	validation_1-logloss:0.00052
# [103]	validation_0-logloss:0.000342	validation_1-logloss:0.00052
# [104]	validation_0-logloss:0.000341	validation_1-logloss:0.00052
# [105]	validation_0-logloss:0.000341	validation_1-logloss:0.00052
# [106]	validation_0-logloss:0.000341	validation_1-logloss:0.00052
# [107]	validation_0-logloss:0.00034	validation_1-logloss:0.000521
# [108]	validation_0-logloss:0.00034	validation_1-logloss:0.000521
# Stopping. Best iteration:
# [98]	validation_0-logloss:0.000345	validation_1-logloss:0.00052
#   8%|▊         | 2/24 [03:30<39:22, 107.38s/it]
# ind_cco_fin_ult1
# [0]	validation_0-logloss:0.604221	validation_1-logloss:0.604186
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.531364	validation_1-logloss:0.53132
# [2]	validation_0-logloss:0.470484	validation_1-logloss:0.470429
# [3]	validation_0-logloss:0.419246	validation_1-logloss:0.419195
# [4]	validation_0-logloss:0.376088	validation_1-logloss:0.376048
# [5]	validation_0-logloss:0.338449	validation_1-logloss:0.338407
# [6]	validation_0-logloss:0.305929	validation_1-logloss:0.305883
# [7]	validation_0-logloss:0.277441	validation_1-logloss:0.277382
# [8]	validation_0-logloss:0.252633	validation_1-logloss:0.252585
# [9]	validation_0-logloss:0.230971	validation_1-logloss:0.230924
# [10]	validation_0-logloss:0.21193	validation_1-logloss:0.211877
# [11]	validation_0-logloss:0.195085	validation_1-logloss:0.19503
# [12]	validation_0-logloss:0.180219	validation_1-logloss:0.180152
# [13]	validation_0-logloss:0.167179	validation_1-logloss:0.167155
# [14]	validation_0-logloss:0.155537	validation_1-logloss:0.155514
# [15]	validation_0-logloss:0.144981	validation_1-logloss:0.144984
# [16]	validation_0-logloss:0.135861	validation_1-logloss:0.135899
# [17]	validation_0-logloss:0.127549	validation_1-logloss:0.127603
# [18]	validation_0-logloss:0.120457	validation_1-logloss:0.12054
# [19]	validation_0-logloss:0.113786	validation_1-logloss:0.113896
# [20]	validation_0-logloss:0.107954	validation_1-logloss:0.108087
# [21]	validation_0-logloss:0.102814	validation_1-logloss:0.102971
# [22]	validation_0-logloss:0.098198	validation_1-logloss:0.098369
# [23]	validation_0-logloss:0.094094	validation_1-logloss:0.094298
# [24]	validation_0-logloss:0.090378	validation_1-logloss:0.090608
# [25]	validation_0-logloss:0.087065	validation_1-logloss:0.087328
# [26]	validation_0-logloss:0.084004	validation_1-logloss:0.0843
# [27]	validation_0-logloss:0.081392	validation_1-logloss:0.081703
# [28]	validation_0-logloss:0.078994	validation_1-logloss:0.079344
# [29]	validation_0-logloss:0.076916	validation_1-logloss:0.077288
# [30]	validation_0-logloss:0.075016	validation_1-logloss:0.075419
# [31]	validation_0-logloss:0.073304	validation_1-logloss:0.073714
# [32]	validation_0-logloss:0.071794	validation_1-logloss:0.072234
# [33]	validation_0-logloss:0.070454	validation_1-logloss:0.070893
# [34]	validation_0-logloss:0.069213	validation_1-logloss:0.069684
# [35]	validation_0-logloss:0.068188	validation_1-logloss:0.068677
# [36]	validation_0-logloss:0.067259	validation_1-logloss:0.067774
# [37]	validation_0-logloss:0.066394	validation_1-logloss:0.066934
# [38]	validation_0-logloss:0.06561	validation_1-logloss:0.066177
# [39]	validation_0-logloss:0.064913	validation_1-logloss:0.065508
# [40]	validation_0-logloss:0.064336	validation_1-logloss:0.064948
# [41]	validation_0-logloss:0.063792	validation_1-logloss:0.064424
# [42]	validation_0-logloss:0.063301	validation_1-logloss:0.063965
# [43]	validation_0-logloss:0.062843	validation_1-logloss:0.063525
# [44]	validation_0-logloss:0.062495	validation_1-logloss:0.063202
# [45]	validation_0-logloss:0.06219	validation_1-logloss:0.062909
# [46]	validation_0-logloss:0.061914	validation_1-logloss:0.062651
# [47]	validation_0-logloss:0.061642	validation_1-logloss:0.062411
# [48]	validation_0-logloss:0.061393	validation_1-logloss:0.062193
# [49]	validation_0-logloss:0.061142	validation_1-logloss:0.061958
# [50]	validation_0-logloss:0.060953	validation_1-logloss:0.061788
# [51]	validation_0-logloss:0.060767	validation_1-logloss:0.061617
# [52]	validation_0-logloss:0.060582	validation_1-logloss:0.061441
# [53]	validation_0-logloss:0.060419	validation_1-logloss:0.061287
# [54]	validation_0-logloss:0.0603	validation_1-logloss:0.061186
# [55]	validation_0-logloss:0.060196	validation_1-logloss:0.061087
# [56]	validation_0-logloss:0.060064	validation_1-logloss:0.06096
# [57]	validation_0-logloss:0.059941	validation_1-logloss:0.060839
# [58]	validation_0-logloss:0.059843	validation_1-logloss:0.060736
# [59]	validation_0-logloss:0.059752	validation_1-logloss:0.060654
# [60]	validation_0-logloss:0.059673	validation_1-logloss:0.060563
# [61]	validation_0-logloss:0.059592	validation_1-logloss:0.060499
# [62]	validation_0-logloss:0.059504	validation_1-logloss:0.060415
# [63]	validation_0-logloss:0.059418	validation_1-logloss:0.060323
# [64]	validation_0-logloss:0.059369	validation_1-logloss:0.060275
# [65]	validation_0-logloss:0.059301	validation_1-logloss:0.060208
# [66]	validation_0-logloss:0.059243	validation_1-logloss:0.060156
# [67]	validation_0-logloss:0.059175	validation_1-logloss:0.060083
# [68]	validation_0-logloss:0.059135	validation_1-logloss:0.060047
# [69]	validation_0-logloss:0.059089	validation_1-logloss:0.059995
# [70]	validation_0-logloss:0.059044	validation_1-logloss:0.059951
# [71]	validation_0-logloss:0.059002	validation_1-logloss:0.059911
# [72]	validation_0-logloss:0.058961	validation_1-logloss:0.059866
# [73]	validation_0-logloss:0.058906	validation_1-logloss:0.059811
# [74]	validation_0-logloss:0.058869	validation_1-logloss:0.059773
# [75]	validation_0-logloss:0.058833	validation_1-logloss:0.059738
# [76]	validation_0-logloss:0.058797	validation_1-logloss:0.059697
# [77]	validation_0-logloss:0.058772	validation_1-logloss:0.059672
# [78]	validation_0-logloss:0.05873	validation_1-logloss:0.059624
# [79]	validation_0-logloss:0.058696	validation_1-logloss:0.059589
# [80]	validation_0-logloss:0.058663	validation_1-logloss:0.059557
# [81]	validation_0-logloss:0.058634	validation_1-logloss:0.059528
# [82]	validation_0-logloss:0.058591	validation_1-logloss:0.05948
# [83]	validation_0-logloss:0.05856	validation_1-logloss:0.05944
# [84]	validation_0-logloss:0.058525	validation_1-logloss:0.05941
# [85]	validation_0-logloss:0.058499	validation_1-logloss:0.059393
# [86]	validation_0-logloss:0.058472	validation_1-logloss:0.059369
# [87]	validation_0-logloss:0.058447	validation_1-logloss:0.059346
# [88]	validation_0-logloss:0.058408	validation_1-logloss:0.059309
# [89]	validation_0-logloss:0.058378	validation_1-logloss:0.059279
# [90]	validation_0-logloss:0.058356	validation_1-logloss:0.059258
# [91]	validation_0-logloss:0.058343	validation_1-logloss:0.059247
# [92]	validation_0-logloss:0.05831	validation_1-logloss:0.059217
# [93]	validation_0-logloss:0.058289	validation_1-logloss:0.059196
# [94]	validation_0-logloss:0.058264	validation_1-logloss:0.059168
# [95]	validation_0-logloss:0.058241	validation_1-logloss:0.059143
# [96]	validation_0-logloss:0.058211	validation_1-logloss:0.059115
# [97]	validation_0-logloss:0.058197	validation_1-logloss:0.059106
# [98]	validation_0-logloss:0.058174	validation_1-logloss:0.059087
# [99]	validation_0-logloss:0.058155	validation_1-logloss:0.059072
# [100]	validation_0-logloss:0.058132	validation_1-logloss:0.059051
# [101]	validation_0-logloss:0.058113	validation_1-logloss:0.059033
# [102]	validation_0-logloss:0.058092	validation_1-logloss:0.059019
# [103]	validation_0-logloss:0.058071	validation_1-logloss:0.058995
# [104]	validation_0-logloss:0.058047	validation_1-logloss:0.058979
# [105]	validation_0-logloss:0.058022	validation_1-logloss:0.058956
# [106]	validation_0-logloss:0.058003	validation_1-logloss:0.058938
# [107]	validation_0-logloss:0.057981	validation_1-logloss:0.058928
# [108]	validation_0-logloss:0.057961	validation_1-logloss:0.058908
# [109]	validation_0-logloss:0.057945	validation_1-logloss:0.058893
# [110]	validation_0-logloss:0.057927	validation_1-logloss:0.058871
# [111]	validation_0-logloss:0.057904	validation_1-logloss:0.058855
# [112]	validation_0-logloss:0.057883	validation_1-logloss:0.05883
# [113]	validation_0-logloss:0.057867	validation_1-logloss:0.058813
# [114]	validation_0-logloss:0.057851	validation_1-logloss:0.058799
# [115]	validation_0-logloss:0.057835	validation_1-logloss:0.058782
# [116]	validation_0-logloss:0.057819	validation_1-logloss:0.058766
# [117]	validation_0-logloss:0.057804	validation_1-logloss:0.058752
# [118]	validation_0-logloss:0.057787	validation_1-logloss:0.058733
# [119]	validation_0-logloss:0.057775	validation_1-logloss:0.058721
# [120]	validation_0-logloss:0.057758	validation_1-logloss:0.058711
# [121]	validation_0-logloss:0.057728	validation_1-logloss:0.058686
# [122]	validation_0-logloss:0.057713	validation_1-logloss:0.058672
# [123]	validation_0-logloss:0.057693	validation_1-logloss:0.058655
# [124]	validation_0-logloss:0.057679	validation_1-logloss:0.058639
# [125]	validation_0-logloss:0.057671	validation_1-logloss:0.05864
# [126]	validation_0-logloss:0.057661	validation_1-logloss:0.058631
# [127]	validation_0-logloss:0.057644	validation_1-logloss:0.058615
# [128]	validation_0-logloss:0.057628	validation_1-logloss:0.058603
# [129]	validation_0-logloss:0.057616	validation_1-logloss:0.058586
# [130]	validation_0-logloss:0.057595	validation_1-logloss:0.05856
# [131]	validation_0-logloss:0.057579	validation_1-logloss:0.058549
# [132]	validation_0-logloss:0.057561	validation_1-logloss:0.058531
# [133]	validation_0-logloss:0.057543	validation_1-logloss:0.058513
# [134]	validation_0-logloss:0.057526	validation_1-logloss:0.058496
# [135]	validation_0-logloss:0.057513	validation_1-logloss:0.058486
# [136]	validation_0-logloss:0.057496	validation_1-logloss:0.058471
# [137]	validation_0-logloss:0.057483	validation_1-logloss:0.058455
# [138]	validation_0-logloss:0.057466	validation_1-logloss:0.05844
# [139]	validation_0-logloss:0.05745	validation_1-logloss:0.058424
# [140]	validation_0-logloss:0.05743	validation_1-logloss:0.058409
# [141]	validation_0-logloss:0.057412	validation_1-logloss:0.058394
# [142]	validation_0-logloss:0.057394	validation_1-logloss:0.058375
# [143]	validation_0-logloss:0.057376	validation_1-logloss:0.058359
# [144]	validation_0-logloss:0.057363	validation_1-logloss:0.058344
# [145]	validation_0-logloss:0.057352	validation_1-logloss:0.058336
# [146]	validation_0-logloss:0.057338	validation_1-logloss:0.058324
# [147]	validation_0-logloss:0.057324	validation_1-logloss:0.058309
# [148]	validation_0-logloss:0.05731	validation_1-logloss:0.058291
# [149]	validation_0-logloss:0.057299	validation_1-logloss:0.058286
# [150]	validation_0-logloss:0.057282	validation_1-logloss:0.058267
# [151]	validation_0-logloss:0.057266	validation_1-logloss:0.058249
# [152]	validation_0-logloss:0.057255	validation_1-logloss:0.058242
# [153]	validation_0-logloss:0.057243	validation_1-logloss:0.058229
# [154]	validation_0-logloss:0.05723	validation_1-logloss:0.058222
# [155]	validation_0-logloss:0.057221	validation_1-logloss:0.058216
# [156]	validation_0-logloss:0.05721	validation_1-logloss:0.058206
# [157]	validation_0-logloss:0.057192	validation_1-logloss:0.058192
# [158]	validation_0-logloss:0.057176	validation_1-logloss:0.058179
# [159]	validation_0-logloss:0.057164	validation_1-logloss:0.058172
# [160]	validation_0-logloss:0.057153	validation_1-logloss:0.058163
# [161]	validation_0-logloss:0.05714	validation_1-logloss:0.058153
# [162]	validation_0-logloss:0.057128	validation_1-logloss:0.058142
# [163]	validation_0-logloss:0.057115	validation_1-logloss:0.058136
# [164]	validation_0-logloss:0.057099	validation_1-logloss:0.058128
# [165]	validation_0-logloss:0.057086	validation_1-logloss:0.058116
# [166]	validation_0-logloss:0.057074	validation_1-logloss:0.058103
# [167]	validation_0-logloss:0.057059	validation_1-logloss:0.058091
# [168]	validation_0-logloss:0.057045	validation_1-logloss:0.058075
# [169]	validation_0-logloss:0.057033	validation_1-logloss:0.058059
# [170]	validation_0-logloss:0.057018	validation_1-logloss:0.058041
# [171]	validation_0-logloss:0.057005	validation_1-logloss:0.058032
# [172]	validation_0-logloss:0.056992	validation_1-logloss:0.058028
# [173]	validation_0-logloss:0.056981	validation_1-logloss:0.058019
# [174]	validation_0-logloss:0.056974	validation_1-logloss:0.058012
# [175]	validation_0-logloss:0.05696	validation_1-logloss:0.057996
# [176]	validation_0-logloss:0.056949	validation_1-logloss:0.057982
# [177]	validation_0-logloss:0.056935	validation_1-logloss:0.057967
# [178]	validation_0-logloss:0.056922	validation_1-logloss:0.057958
# [179]	validation_0-logloss:0.056911	validation_1-logloss:0.057951
# [180]	validation_0-logloss:0.056899	validation_1-logloss:0.057942
# [181]	validation_0-logloss:0.056886	validation_1-logloss:0.057929
# [182]	validation_0-logloss:0.056876	validation_1-logloss:0.057926
# [183]	validation_0-logloss:0.056865	validation_1-logloss:0.057916
# [184]	validation_0-logloss:0.056857	validation_1-logloss:0.05791
# [185]	validation_0-logloss:0.056839	validation_1-logloss:0.057904
# [186]	validation_0-logloss:0.056823	validation_1-logloss:0.057892
# [187]	validation_0-logloss:0.05681	validation_1-logloss:0.057873
# [188]	validation_0-logloss:0.056795	validation_1-logloss:0.057862
# [189]	validation_0-logloss:0.056785	validation_1-logloss:0.057852
# [190]	validation_0-logloss:0.056777	validation_1-logloss:0.057846
# [191]	validation_0-logloss:0.056767	validation_1-logloss:0.057838
# [192]	validation_0-logloss:0.056754	validation_1-logloss:0.057825
# [193]	validation_0-logloss:0.056742	validation_1-logloss:0.057816
# [194]	validation_0-logloss:0.056732	validation_1-logloss:0.057809
# [195]	validation_0-logloss:0.056722	validation_1-logloss:0.057803
# [196]	validation_0-logloss:0.056712	validation_1-logloss:0.057795
# [197]	validation_0-logloss:0.056703	validation_1-logloss:0.057792
# [198]	validation_0-logloss:0.056694	validation_1-logloss:0.057791
# [199]	validation_0-logloss:0.056682	validation_1-logloss:0.057778
# [200]	validation_0-logloss:0.056672	validation_1-logloss:0.057774
# [201]	validation_0-logloss:0.056663	validation_1-logloss:0.057766
# [202]	validation_0-logloss:0.056652	validation_1-logloss:0.057758
# [203]	validation_0-logloss:0.056643	validation_1-logloss:0.057747
# [204]	validation_0-logloss:0.056636	validation_1-logloss:0.057743
# [205]	validation_0-logloss:0.05662	validation_1-logloss:0.057734
# [206]	validation_0-logloss:0.056609	validation_1-logloss:0.057726
# [207]	validation_0-logloss:0.056598	validation_1-logloss:0.057716
# [208]	validation_0-logloss:0.056587	validation_1-logloss:0.057704
# [209]	validation_0-logloss:0.056579	validation_1-logloss:0.057696
# [210]	validation_0-logloss:0.05657	validation_1-logloss:0.057682
# [211]	validation_0-logloss:0.056561	validation_1-logloss:0.057672
# [212]	validation_0-logloss:0.056553	validation_1-logloss:0.057667
# [213]	validation_0-logloss:0.056544	validation_1-logloss:0.057657
# [214]	validation_0-logloss:0.056531	validation_1-logloss:0.057639
# [215]	validation_0-logloss:0.056521	validation_1-logloss:0.057631
# [216]	validation_0-logloss:0.056511	validation_1-logloss:0.057622
# [217]	validation_0-logloss:0.056503	validation_1-logloss:0.057611
# [218]	validation_0-logloss:0.056494	validation_1-logloss:0.057604
# [219]	validation_0-logloss:0.056485	validation_1-logloss:0.057601
# [220]	validation_0-logloss:0.05648	validation_1-logloss:0.0576
# [221]	validation_0-logloss:0.056468	validation_1-logloss:0.057587
# [222]	validation_0-logloss:0.056458	validation_1-logloss:0.057578
# [223]	validation_0-logloss:0.056453	validation_1-logloss:0.057576
# [224]	validation_0-logloss:0.05644	validation_1-logloss:0.057568
# [225]	validation_0-logloss:0.056429	validation_1-logloss:0.057557
# [226]	validation_0-logloss:0.056421	validation_1-logloss:0.057561
# [227]	validation_0-logloss:0.056409	validation_1-logloss:0.057543
# [228]	validation_0-logloss:0.056401	validation_1-logloss:0.057539
# [229]	validation_0-logloss:0.056388	validation_1-logloss:0.057533
# [230]	validation_0-logloss:0.056377	validation_1-logloss:0.057522
# [231]	validation_0-logloss:0.056369	validation_1-logloss:0.057515
# [232]	validation_0-logloss:0.056358	validation_1-logloss:0.05751
# [233]	validation_0-logloss:0.056348	validation_1-logloss:0.057501
# [234]	validation_0-logloss:0.056338	validation_1-logloss:0.057492
# [235]	validation_0-logloss:0.05633	validation_1-logloss:0.057485
# [236]	validation_0-logloss:0.056326	validation_1-logloss:0.057487
# [237]	validation_0-logloss:0.056321	validation_1-logloss:0.057486
# [238]	validation_0-logloss:0.056314	validation_1-logloss:0.057483
# [239]	validation_0-logloss:0.056307	validation_1-logloss:0.05748
# [240]	validation_0-logloss:0.056301	validation_1-logloss:0.057475
# [241]	validation_0-logloss:0.056292	validation_1-logloss:0.057467
# [242]	validation_0-logloss:0.056284	validation_1-logloss:0.057462
# [243]	validation_0-logloss:0.056274	validation_1-logloss:0.05745
# [244]	validation_0-logloss:0.056264	validation_1-logloss:0.057441
# [245]	validation_0-logloss:0.056256	validation_1-logloss:0.057435
# [246]	validation_0-logloss:0.056245	validation_1-logloss:0.057419
# [247]	validation_0-logloss:0.056237	validation_1-logloss:0.057407
# [248]	validation_0-logloss:0.056227	validation_1-logloss:0.057394
# [249]	validation_0-logloss:0.056221	validation_1-logloss:0.057388
# [250]	validation_0-logloss:0.056212	validation_1-logloss:0.057379
# [251]	validation_0-logloss:0.056199	validation_1-logloss:0.057367
# [252]	validation_0-logloss:0.056191	validation_1-logloss:0.057362
# [253]	validation_0-logloss:0.056183	validation_1-logloss:0.057357
# [254]	validation_0-logloss:0.056172	validation_1-logloss:0.057346
# [255]	validation_0-logloss:0.056162	validation_1-logloss:0.05734
# [256]	validation_0-logloss:0.056155	validation_1-logloss:0.057335
# [257]	validation_0-logloss:0.056148	validation_1-logloss:0.057334
# [258]	validation_0-logloss:0.056137	validation_1-logloss:0.057321
# [259]	validation_0-logloss:0.056129	validation_1-logloss:0.057311
# [260]	validation_0-logloss:0.056121	validation_1-logloss:0.057307
# [261]	validation_0-logloss:0.056114	validation_1-logloss:0.057305
# [262]	validation_0-logloss:0.056106	validation_1-logloss:0.0573
# [263]	validation_0-logloss:0.056097	validation_1-logloss:0.057292
# [264]	validation_0-logloss:0.056091	validation_1-logloss:0.05729
# [265]	validation_0-logloss:0.056085	validation_1-logloss:0.057288
# [266]	validation_0-logloss:0.056077	validation_1-logloss:0.057279
# [267]	validation_0-logloss:0.05607	validation_1-logloss:0.057275
# [268]	validation_0-logloss:0.056067	validation_1-logloss:0.057276
# [269]	validation_0-logloss:0.05606	validation_1-logloss:0.057268
# [270]	validation_0-logloss:0.056054	validation_1-logloss:0.057264
# [271]	validation_0-logloss:0.056045	validation_1-logloss:0.057253
# [272]	validation_0-logloss:0.05604	validation_1-logloss:0.057253
# [273]	validation_0-logloss:0.056033	validation_1-logloss:0.057249
# [274]	validation_0-logloss:0.056027	validation_1-logloss:0.057244
# [275]	validation_0-logloss:0.056017	validation_1-logloss:0.057239
# [276]	validation_0-logloss:0.05601	validation_1-logloss:0.057233
# [277]	validation_0-logloss:0.056005	validation_1-logloss:0.057231
# [278]	validation_0-logloss:0.055995	validation_1-logloss:0.057225
# [279]	validation_0-logloss:0.05599	validation_1-logloss:0.057223
# [280]	validation_0-logloss:0.055978	validation_1-logloss:0.057205
# [281]	validation_0-logloss:0.055973	validation_1-logloss:0.057201
# [282]	validation_0-logloss:0.055966	validation_1-logloss:0.057198
# [283]	validation_0-logloss:0.055961	validation_1-logloss:0.057194
# [284]	validation_0-logloss:0.055957	validation_1-logloss:0.057191
# [285]	validation_0-logloss:0.055949	validation_1-logloss:0.057183
# [286]	validation_0-logloss:0.05594	validation_1-logloss:0.05718
# [287]	validation_0-logloss:0.055933	validation_1-logloss:0.057175
# [288]	validation_0-logloss:0.055924	validation_1-logloss:0.057162
# [289]	validation_0-logloss:0.055918	validation_1-logloss:0.057158
# [290]	validation_0-logloss:0.055914	validation_1-logloss:0.057158
# [291]	validation_0-logloss:0.055906	validation_1-logloss:0.057156
# [292]	validation_0-logloss:0.055899	validation_1-logloss:0.057153
# [293]	validation_0-logloss:0.055892	validation_1-logloss:0.057149
# [294]	validation_0-logloss:0.055885	validation_1-logloss:0.057139
# [295]	validation_0-logloss:0.055881	validation_1-logloss:0.057137
# [296]	validation_0-logloss:0.055873	validation_1-logloss:0.057132
# [297]	validation_0-logloss:0.055866	validation_1-logloss:0.057128
# [298]	validation_0-logloss:0.055861	validation_1-logloss:0.057123
# [299]	validation_0-logloss:0.055858	validation_1-logloss:0.057127
# [300]	validation_0-logloss:0.05585	validation_1-logloss:0.057121
# [301]	validation_0-logloss:0.055845	validation_1-logloss:0.057118
# [302]	validation_0-logloss:0.055837	validation_1-logloss:0.057114
# [303]	validation_0-logloss:0.055828	validation_1-logloss:0.057102
# [304]	validation_0-logloss:0.055821	validation_1-logloss:0.057094
# [305]	validation_0-logloss:0.055812	validation_1-logloss:0.057083
# [306]	validation_0-logloss:0.055807	validation_1-logloss:0.057085
# [307]	validation_0-logloss:0.0558	validation_1-logloss:0.057083
# [308]	validation_0-logloss:0.055792	validation_1-logloss:0.057075
# [309]	validation_0-logloss:0.055787	validation_1-logloss:0.057068
# [310]	validation_0-logloss:0.055783	validation_1-logloss:0.057069
# [311]	validation_0-logloss:0.055777	validation_1-logloss:0.057065
# [312]	validation_0-logloss:0.055773	validation_1-logloss:0.057063
# [313]	validation_0-logloss:0.055764	validation_1-logloss:0.057055
# [314]	validation_0-logloss:0.055759	validation_1-logloss:0.057049
# [315]	validation_0-logloss:0.055754	validation_1-logloss:0.05705
# [316]	validation_0-logloss:0.055747	validation_1-logloss:0.057044
# [317]	validation_0-logloss:0.055741	validation_1-logloss:0.057036
# [318]	validation_0-logloss:0.055737	validation_1-logloss:0.057037
# [319]	validation_0-logloss:0.05573	validation_1-logloss:0.057032
# [320]	validation_0-logloss:0.055723	validation_1-logloss:0.057028
# [321]	validation_0-logloss:0.055719	validation_1-logloss:0.057024
# [322]	validation_0-logloss:0.055713	validation_1-logloss:0.057022
# [323]	validation_0-logloss:0.055707	validation_1-logloss:0.057014
# [324]	validation_0-logloss:0.055702	validation_1-logloss:0.057009
# [325]	validation_0-logloss:0.055696	validation_1-logloss:0.057004
# [326]	validation_0-logloss:0.055688	validation_1-logloss:0.057
# [327]	validation_0-logloss:0.055684	validation_1-logloss:0.056996
# [328]	validation_0-logloss:0.055677	validation_1-logloss:0.056991
# [329]	validation_0-logloss:0.05567	validation_1-logloss:0.056988
# [330]	validation_0-logloss:0.055665	validation_1-logloss:0.056985
# [331]	validation_0-logloss:0.05566	validation_1-logloss:0.056976
# [332]	validation_0-logloss:0.055653	validation_1-logloss:0.056968
# [333]	validation_0-logloss:0.055647	validation_1-logloss:0.056964
# [334]	validation_0-logloss:0.055639	validation_1-logloss:0.056959
# [335]	validation_0-logloss:0.055633	validation_1-logloss:0.056956
# [336]	validation_0-logloss:0.055628	validation_1-logloss:0.056956
# [337]	validation_0-logloss:0.055615	validation_1-logloss:0.056949
# [338]	validation_0-logloss:0.05561	validation_1-logloss:0.056945
# [339]	validation_0-logloss:0.055606	validation_1-logloss:0.056944
# [340]	validation_0-logloss:0.055601	validation_1-logloss:0.056941
# [341]	validation_0-logloss:0.055595	validation_1-logloss:0.056938
# [342]	validation_0-logloss:0.05559	validation_1-logloss:0.056938
# [343]	validation_0-logloss:0.055582	validation_1-logloss:0.056928
# [344]	validation_0-logloss:0.055578	validation_1-logloss:0.056927
# [345]	validation_0-logloss:0.055575	validation_1-logloss:0.056926
# [346]	validation_0-logloss:0.05557	validation_1-logloss:0.056922
# [347]	validation_0-logloss:0.055568	validation_1-logloss:0.056925
# [348]	validation_0-logloss:0.055563	validation_1-logloss:0.056924
# [349]	validation_0-logloss:0.055558	validation_1-logloss:0.05692
# [350]	validation_0-logloss:0.055553	validation_1-logloss:0.056917
# [351]	validation_0-logloss:0.055545	validation_1-logloss:0.05691
# [352]	validation_0-logloss:0.055541	validation_1-logloss:0.056905
# [353]	validation_0-logloss:0.055534	validation_1-logloss:0.056897
# [354]	validation_0-logloss:0.055528	validation_1-logloss:0.056893
# [355]	validation_0-logloss:0.055523	validation_1-logloss:0.056884
# [356]	validation_0-logloss:0.055516	validation_1-logloss:0.056883
# [357]	validation_0-logloss:0.055511	validation_1-logloss:0.056882
# [358]	validation_0-logloss:0.055503	validation_1-logloss:0.056877
# [359]	validation_0-logloss:0.055497	validation_1-logloss:0.056872
# [360]	validation_0-logloss:0.055491	validation_1-logloss:0.056872
# [361]	validation_0-logloss:0.055482	validation_1-logloss:0.056866
# [362]	validation_0-logloss:0.055476	validation_1-logloss:0.056859
# [363]	validation_0-logloss:0.055466	validation_1-logloss:0.056849
# [364]	validation_0-logloss:0.055461	validation_1-logloss:0.056845
# [365]	validation_0-logloss:0.055453	validation_1-logloss:0.056838
# [366]	validation_0-logloss:0.055451	validation_1-logloss:0.056839
# [367]	validation_0-logloss:0.055444	validation_1-logloss:0.056832
# [368]	validation_0-logloss:0.055439	validation_1-logloss:0.05683
# [369]	validation_0-logloss:0.055434	validation_1-logloss:0.056822
# [370]	validation_0-logloss:0.055429	validation_1-logloss:0.056826
# [371]	validation_0-logloss:0.055421	validation_1-logloss:0.056814
# [372]	validation_0-logloss:0.055417	validation_1-logloss:0.056814
# [373]	validation_0-logloss:0.055413	validation_1-logloss:0.056814
# [374]	validation_0-logloss:0.055409	validation_1-logloss:0.056807
# [375]	validation_0-logloss:0.0554	validation_1-logloss:0.056798
# [376]	validation_0-logloss:0.055394	validation_1-logloss:0.056791
# [377]	validation_0-logloss:0.055385	validation_1-logloss:0.056787
# [378]	validation_0-logloss:0.055382	validation_1-logloss:0.056786
# [379]	validation_0-logloss:0.055377	validation_1-logloss:0.056782
# [380]	validation_0-logloss:0.05537	validation_1-logloss:0.056781
# [381]	validation_0-logloss:0.055363	validation_1-logloss:0.056779
# [382]	validation_0-logloss:0.055359	validation_1-logloss:0.056774
# [383]	validation_0-logloss:0.055354	validation_1-logloss:0.056771
# [384]	validation_0-logloss:0.055349	validation_1-logloss:0.056766
# [385]	validation_0-logloss:0.055345	validation_1-logloss:0.056762
# [386]	validation_0-logloss:0.055341	validation_1-logloss:0.056763
# [387]	validation_0-logloss:0.055334	validation_1-logloss:0.056755
# [388]	validation_0-logloss:0.055331	validation_1-logloss:0.056756
# [389]	validation_0-logloss:0.055327	validation_1-logloss:0.056756
# [390]	validation_0-logloss:0.055321	validation_1-logloss:0.056754
# [391]	validation_0-logloss:0.055316	validation_1-logloss:0.056749
# [392]	validation_0-logloss:0.055313	validation_1-logloss:0.056748
# [393]	validation_0-logloss:0.055305	validation_1-logloss:0.056741
# [394]	validation_0-logloss:0.055298	validation_1-logloss:0.056736
# [395]	validation_0-logloss:0.055292	validation_1-logloss:0.056729
# [396]	validation_0-logloss:0.055288	validation_1-logloss:0.056725
# [397]	validation_0-logloss:0.055283	validation_1-logloss:0.056721
# [398]	validation_0-logloss:0.055277	validation_1-logloss:0.056714
# [399]	validation_0-logloss:0.055272	validation_1-logloss:0.056711
# [400]	validation_0-logloss:0.055266	validation_1-logloss:0.056706
# [401]	validation_0-logloss:0.055261	validation_1-logloss:0.056707
# [402]	validation_0-logloss:0.055255	validation_1-logloss:0.056706
# [403]	validation_0-logloss:0.05525	validation_1-logloss:0.056702
# [404]	validation_0-logloss:0.055244	validation_1-logloss:0.056695
# [405]	validation_0-logloss:0.055238	validation_1-logloss:0.056689
# [406]	validation_0-logloss:0.055232	validation_1-logloss:0.056682
# [407]	validation_0-logloss:0.055227	validation_1-logloss:0.056676
# [408]	validation_0-logloss:0.055222	validation_1-logloss:0.056672
# [409]	validation_0-logloss:0.055218	validation_1-logloss:0.056669
# [410]	validation_0-logloss:0.055213	validation_1-logloss:0.056666
# [411]	validation_0-logloss:0.055208	validation_1-logloss:0.056666
# [412]	validation_0-logloss:0.0552	validation_1-logloss:0.056665
# [413]	validation_0-logloss:0.055197	validation_1-logloss:0.056665
# [414]	validation_0-logloss:0.055193	validation_1-logloss:0.056666
# [415]	validation_0-logloss:0.055186	validation_1-logloss:0.056659
# [416]	validation_0-logloss:0.055181	validation_1-logloss:0.056655
# [417]	validation_0-logloss:0.055175	validation_1-logloss:0.056657
# [418]	validation_0-logloss:0.055171	validation_1-logloss:0.056653
# [419]	validation_0-logloss:0.055169	validation_1-logloss:0.056652
# [420]	validation_0-logloss:0.055163	validation_1-logloss:0.056646
# [421]	validation_0-logloss:0.055158	validation_1-logloss:0.056645
# [422]	validation_0-logloss:0.055155	validation_1-logloss:0.056641
# [423]	validation_0-logloss:0.055149	validation_1-logloss:0.056636
# [424]	validation_0-logloss:0.055146	validation_1-logloss:0.056631
# [425]	validation_0-logloss:0.055142	validation_1-logloss:0.056628
# [426]	validation_0-logloss:0.055137	validation_1-logloss:0.056625
# [427]	validation_0-logloss:0.055131	validation_1-logloss:0.05662
# [428]	validation_0-logloss:0.055128	validation_1-logloss:0.056619
# [429]	validation_0-logloss:0.055122	validation_1-logloss:0.056622
# [430]	validation_0-logloss:0.055117	validation_1-logloss:0.05662
# [431]	validation_0-logloss:0.055112	validation_1-logloss:0.056618
# [432]	validation_0-logloss:0.055108	validation_1-logloss:0.056618
# [433]	validation_0-logloss:0.055104	validation_1-logloss:0.056609
# [434]	validation_0-logloss:0.0551	validation_1-logloss:0.056608
# [435]	validation_0-logloss:0.055096	validation_1-logloss:0.056605
# [436]	validation_0-logloss:0.055093	validation_1-logloss:0.056604
# [437]	validation_0-logloss:0.05509	validation_1-logloss:0.056602
# [438]	validation_0-logloss:0.055086	validation_1-logloss:0.056597
# [439]	validation_0-logloss:0.055083	validation_1-logloss:0.056597
# [440]	validation_0-logloss:0.055079	validation_1-logloss:0.056594
# [441]	validation_0-logloss:0.055073	validation_1-logloss:0.056583
# [442]	validation_0-logloss:0.055069	validation_1-logloss:0.056578
# [443]	validation_0-logloss:0.055064	validation_1-logloss:0.056576
# [444]	validation_0-logloss:0.055057	validation_1-logloss:0.056569
# [445]	validation_0-logloss:0.055054	validation_1-logloss:0.056568
# [446]	validation_0-logloss:0.055049	validation_1-logloss:0.056564
# [447]	validation_0-logloss:0.055044	validation_1-logloss:0.056562
# [448]	validation_0-logloss:0.055038	validation_1-logloss:0.056562
# [449]	validation_0-logloss:0.055033	validation_1-logloss:0.056558
# [450]	validation_0-logloss:0.055029	validation_1-logloss:0.056557
# [451]	validation_0-logloss:0.055027	validation_1-logloss:0.05656
# [452]	validation_0-logloss:0.055023	validation_1-logloss:0.056556
# [453]	validation_0-logloss:0.05502	validation_1-logloss:0.056556
# [454]	validation_0-logloss:0.055015	validation_1-logloss:0.056554
# [455]	validation_0-logloss:0.055011	validation_1-logloss:0.056553
# [456]	validation_0-logloss:0.055009	validation_1-logloss:0.056551
# [457]	validation_0-logloss:0.055004	validation_1-logloss:0.056547
# [458]	validation_0-logloss:0.055001	validation_1-logloss:0.056547
# [459]	validation_0-logloss:0.054997	validation_1-logloss:0.056541
# [460]	validation_0-logloss:0.054993	validation_1-logloss:0.056541
# [461]	validation_0-logloss:0.054989	validation_1-logloss:0.05654
# [462]	validation_0-logloss:0.054981	validation_1-logloss:0.056534
# [463]	validation_0-logloss:0.054976	validation_1-logloss:0.056536
# [464]	validation_0-logloss:0.054971	validation_1-logloss:0.056531
# [465]	validation_0-logloss:0.054967	validation_1-logloss:0.05653
# [466]	validation_0-logloss:0.054963	validation_1-logloss:0.056524
# [467]	validation_0-logloss:0.054957	validation_1-logloss:0.05652
# [468]	validation_0-logloss:0.054953	validation_1-logloss:0.056515
# [469]	validation_0-logloss:0.054948	validation_1-logloss:0.056514
# [470]	validation_0-logloss:0.054945	validation_1-logloss:0.056516
# [471]	validation_0-logloss:0.05494	validation_1-logloss:0.056514
# [472]	validation_0-logloss:0.054936	validation_1-logloss:0.056513
# [473]	validation_0-logloss:0.054932	validation_1-logloss:0.056513
# [474]	validation_0-logloss:0.054928	validation_1-logloss:0.056512
# [475]	validation_0-logloss:0.054924	validation_1-logloss:0.05651
# [476]	validation_0-logloss:0.054919	validation_1-logloss:0.05651
# [477]	validation_0-logloss:0.054917	validation_1-logloss:0.056507
# [478]	validation_0-logloss:0.054913	validation_1-logloss:0.056506
# [479]	validation_0-logloss:0.054909	validation_1-logloss:0.056503
# [480]	validation_0-logloss:0.054905	validation_1-logloss:0.056501
# [481]	validation_0-logloss:0.054902	validation_1-logloss:0.056496
# [482]	validation_0-logloss:0.054899	validation_1-logloss:0.056493
# [483]	validation_0-logloss:0.054894	validation_1-logloss:0.056493
# [484]	validation_0-logloss:0.054891	validation_1-logloss:0.056492
# [485]	validation_0-logloss:0.054889	validation_1-logloss:0.05649
# [486]	validation_0-logloss:0.054883	validation_1-logloss:0.05648
# [487]	validation_0-logloss:0.054879	validation_1-logloss:0.056477
# [488]	validation_0-logloss:0.054874	validation_1-logloss:0.056473
# [489]	validation_0-logloss:0.054871	validation_1-logloss:0.056469
# [490]	validation_0-logloss:0.054867	validation_1-logloss:0.056467
# [491]	validation_0-logloss:0.054863	validation_1-logloss:0.056467
# [492]	validation_0-logloss:0.054861	validation_1-logloss:0.056468
# [493]	validation_0-logloss:0.054858	validation_1-logloss:0.056469
# [494]	validation_0-logloss:0.054853	validation_1-logloss:0.056463
# [495]	validation_0-logloss:0.054851	validation_1-logloss:0.056464
# ...
# [25]	validation_0-logloss:0.09468	validation_1-logloss:0.094625
# [26]	validation_0-logloss:0.09168	validation_1-logloss:0.091634
# [27]	validation_0-logloss:0.089129	validation_1-logloss:0.089088
# [28]	validation_0-logloss:0.086787	validation_1-logloss:0.086769
# [29]	validation_0-logloss:0.084806	validation_1-logloss:0.084792
# [30]	validation_0-logloss:0.082961	validation_1-logloss:0.082955
# [31]	validation_0-logloss:0.081323	validation_1-logloss:0.081339
# [32]	validation_0-logloss:0.07989	validation_1-logloss:0.079907
# [33]	validation_0-logloss:0.078657	validation_1-logloss:0.078673
# [34]	validation_0-logloss:0.077407	validation_1-logloss:0.077434
# [35]	validation_0-logloss:0.07642	validation_1-logloss:0.076461
# [36]	validation_0-logloss:0.075522	validation_1-logloss:0.07558
# [37]	validation_0-logloss:0.074594	validation_1-logloss:0.074666
# [38]	validation_0-logloss:0.073801	validation_1-logloss:0.073875
# [39]	validation_0-logloss:0.073039	validation_1-logloss:0.073121
# [40]	validation_0-logloss:0.072355	validation_1-logloss:0.072454
# [41]	validation_0-logloss:0.071766	validation_1-logloss:0.071878
# [42]	validation_0-logloss:0.071263	validation_1-logloss:0.071388
# [43]	validation_0-logloss:0.070793	validation_1-logloss:0.070928
# [44]	validation_0-logloss:0.070396	validation_1-logloss:0.070534
# [45]	validation_0-logloss:0.070013	validation_1-logloss:0.070165
# [46]	validation_0-logloss:0.069765	validation_1-logloss:0.069927
# [47]	validation_0-logloss:0.0695	validation_1-logloss:0.069671
# [48]	validation_0-logloss:0.069235	validation_1-logloss:0.069408
# [49]	validation_0-logloss:0.068996	validation_1-logloss:0.069177
# [50]	validation_0-logloss:0.068784	validation_1-logloss:0.068975
# [51]	validation_0-logloss:0.06858	validation_1-logloss:0.068791
# [52]	validation_0-logloss:0.068412	validation_1-logloss:0.068636
# [53]	validation_0-logloss:0.068301	validation_1-logloss:0.068543
# [54]	validation_0-logloss:0.068149	validation_1-logloss:0.068403
# [55]	validation_0-logloss:0.06802	validation_1-logloss:0.068282
# [56]	validation_0-logloss:0.0679	validation_1-logloss:0.068175
# [57]	validation_0-logloss:0.067793	validation_1-logloss:0.068083
# [58]	validation_0-logloss:0.067696	validation_1-logloss:0.067998
# [59]	validation_0-logloss:0.067611	validation_1-logloss:0.067917
# [60]	validation_0-logloss:0.067533	validation_1-logloss:0.067848
# [61]	validation_0-logloss:0.067461	validation_1-logloss:0.067785
# [62]	validation_0-logloss:0.067391	validation_1-logloss:0.067731
# [63]	validation_0-logloss:0.067335	validation_1-logloss:0.06768
# [64]	validation_0-logloss:0.06729	validation_1-logloss:0.067644
# [65]	validation_0-logloss:0.067244	validation_1-logloss:0.067607
# [66]	validation_0-logloss:0.06721	validation_1-logloss:0.067577
# [67]	validation_0-logloss:0.067168	validation_1-logloss:0.067534
# [68]	validation_0-logloss:0.067134	validation_1-logloss:0.06751
# [69]	validation_0-logloss:0.067093	validation_1-logloss:0.067483
# [70]	validation_0-logloss:0.067064	validation_1-logloss:0.067465
# [71]	validation_0-logloss:0.06702	validation_1-logloss:0.067414
# [72]	validation_0-logloss:0.066988	validation_1-logloss:0.067395
# [73]	validation_0-logloss:0.06696	validation_1-logloss:0.067378
# [74]	validation_0-logloss:0.066934	validation_1-logloss:0.067369
# [75]	validation_0-logloss:0.066915	validation_1-logloss:0.067347
# [76]	validation_0-logloss:0.066901	validation_1-logloss:0.067338
# [77]	validation_0-logloss:0.066884	validation_1-logloss:0.067331
# [78]	validation_0-logloss:0.066869	validation_1-logloss:0.067322
# [79]	validation_0-logloss:0.066861	validation_1-logloss:0.067312
# [80]	validation_0-logloss:0.066829	validation_1-logloss:0.067287
# [81]	validation_0-logloss:0.066821	validation_1-logloss:0.067285
# [82]	validation_0-logloss:0.066794	validation_1-logloss:0.067264
# [83]	validation_0-logloss:0.066775	validation_1-logloss:0.067249
# [84]	validation_0-logloss:0.066758	validation_1-logloss:0.067242
# [85]	validation_0-logloss:0.066744	validation_1-logloss:0.067231
# [86]	validation_0-logloss:0.066722	validation_1-logloss:0.067217
# [87]	validation_0-logloss:0.066707	validation_1-logloss:0.067209
# [88]	validation_0-logloss:0.0667	validation_1-logloss:0.067202
# [89]	validation_0-logloss:0.066682	validation_1-logloss:0.067191
# [90]	validation_0-logloss:0.066658	validation_1-logloss:0.067179
# [91]	validation_0-logloss:0.066645	validation_1-logloss:0.067173
# [92]	validation_0-logloss:0.066631	validation_1-logloss:0.067169
# [93]	validation_0-logloss:0.066619	validation_1-logloss:0.067168
# [94]	validation_0-logloss:0.06661	validation_1-logloss:0.067165
# [95]	validation_0-logloss:0.066598	validation_1-logloss:0.067162
# [96]	validation_0-logloss:0.066586	validation_1-logloss:0.067154
# [97]	validation_0-logloss:0.066574	validation_1-logloss:0.067151
# [98]	validation_0-logloss:0.066567	validation_1-logloss:0.067151
# [99]	validation_0-logloss:0.066554	validation_1-logloss:0.067148
# [100]	validation_0-logloss:0.066547	validation_1-logloss:0.067147
# [101]	validation_0-logloss:0.06654	validation_1-logloss:0.067145
# [102]	validation_0-logloss:0.066529	validation_1-logloss:0.067135
# [103]	validation_0-logloss:0.066523	validation_1-logloss:0.067137
# [104]	validation_0-logloss:0.066512	validation_1-logloss:0.067137
# [105]	validation_0-logloss:0.066506	validation_1-logloss:0.067135
# [106]	validation_0-logloss:0.066501	validation_1-logloss:0.067136
# [107]	validation_0-logloss:0.066493	validation_1-logloss:0.067135
# [108]	validation_0-logloss:0.066484	validation_1-logloss:0.067131
# [109]	validation_0-logloss:0.066472	validation_1-logloss:0.067128
# [110]	validation_0-logloss:0.066461	validation_1-logloss:0.067126
# [111]	validation_0-logloss:0.066455	validation_1-logloss:0.067122
# [112]	validation_0-logloss:0.066449	validation_1-logloss:0.067121
# [113]	validation_0-logloss:0.066444	validation_1-logloss:0.067115
# [114]	validation_0-logloss:0.066436	validation_1-logloss:0.067106
# [115]	validation_0-logloss:0.066428	validation_1-logloss:0.067105
# [116]	validation_0-logloss:0.06642	validation_1-logloss:0.067104
# [117]	validation_0-logloss:0.066411	validation_1-logloss:0.0671
# [118]	validation_0-logloss:0.066401	validation_1-logloss:0.067095
# [119]	validation_0-logloss:0.066395	validation_1-logloss:0.067092
# [120]	validation_0-logloss:0.066387	validation_1-logloss:0.06709
# [121]	validation_0-logloss:0.066378	validation_1-logloss:0.067092
# [122]	validation_0-logloss:0.066371	validation_1-logloss:0.06709
# [123]	validation_0-logloss:0.066365	validation_1-logloss:0.067087
# [124]	validation_0-logloss:0.066356	validation_1-logloss:0.067084
# [125]	validation_0-logloss:0.066349	validation_1-logloss:0.067084
# [126]	validation_0-logloss:0.066344	validation_1-logloss:0.067082
# [127]	validation_0-logloss:0.066322	validation_1-logloss:0.067064
# [128]	validation_0-logloss:0.066314	validation_1-logloss:0.067059
# [129]	validation_0-logloss:0.066309	validation_1-logloss:0.067055
# [130]	validation_0-logloss:0.066305	validation_1-logloss:0.067057
# [131]	validation_0-logloss:0.066299	validation_1-logloss:0.067056
# [132]	validation_0-logloss:0.066295	validation_1-logloss:0.067056
# [133]	validation_0-logloss:0.066288	validation_1-logloss:0.067049
# [134]	validation_0-logloss:0.066284	validation_1-logloss:0.067047
# [135]	validation_0-logloss:0.06628	validation_1-logloss:0.067046
# [136]	validation_0-logloss:0.066274	validation_1-logloss:0.067041
# [137]	validation_0-logloss:0.066269	validation_1-logloss:0.06704
# [138]	validation_0-logloss:0.066265	validation_1-logloss:0.067037
# [139]	validation_0-logloss:0.066258	validation_1-logloss:0.067035
# [140]	validation_0-logloss:0.06625	validation_1-logloss:0.067034
# [141]	validation_0-logloss:0.066246	validation_1-logloss:0.067031
# [142]	validation_0-logloss:0.066243	validation_1-logloss:0.067028
# [143]	validation_0-logloss:0.066238	validation_1-logloss:0.067028
# [144]	validation_0-logloss:0.066232	validation_1-logloss:0.067028
# [145]	validation_0-logloss:0.066227	validation_1-logloss:0.06703
# [146]	validation_0-logloss:0.066224	validation_1-logloss:0.06703
# [147]	validation_0-logloss:0.066209	validation_1-logloss:0.067015
# [148]	validation_0-logloss:0.066201	validation_1-logloss:0.067013
# [149]	validation_0-logloss:0.066192	validation_1-logloss:0.067008
# [150]	validation_0-logloss:0.066185	validation_1-logloss:0.067009
# [151]	validation_0-logloss:0.06618	validation_1-logloss:0.067011
# [152]	validation_0-logloss:0.066177	validation_1-logloss:0.067007
# [153]	validation_0-logloss:0.066171	validation_1-logloss:0.067002
# [154]	validation_0-logloss:0.066166	validation_1-logloss:0.066997
# [155]	validation_0-logloss:0.066161	validation_1-logloss:0.066996
# [156]	validation_0-logloss:0.066157	validation_1-logloss:0.066994
# [157]	validation_0-logloss:0.066151	validation_1-logloss:0.066996
# [158]	validation_0-logloss:0.066144	validation_1-logloss:0.066992
# [159]	validation_0-logloss:0.066139	validation_1-logloss:0.066991
# [160]	validation_0-logloss:0.066134	validation_1-logloss:0.066987
# [161]	validation_0-logloss:0.066124	validation_1-logloss:0.066978
# [162]	validation_0-logloss:0.066121	validation_1-logloss:0.066974
# [163]	validation_0-logloss:0.066115	validation_1-logloss:0.066966
# [164]	validation_0-logloss:0.06611	validation_1-logloss:0.066966
# [165]	validation_0-logloss:0.066106	validation_1-logloss:0.066965
# [166]	validation_0-logloss:0.066103	validation_1-logloss:0.066968
# [167]	validation_0-logloss:0.066096	validation_1-logloss:0.066962
# [168]	validation_0-logloss:0.066086	validation_1-logloss:0.066953
# [169]	validation_0-logloss:0.066083	validation_1-logloss:0.066949
# [170]	validation_0-logloss:0.066076	validation_1-logloss:0.066946
# [171]	validation_0-logloss:0.066072	validation_1-logloss:0.066946
# [172]	validation_0-logloss:0.066065	validation_1-logloss:0.066945
# [173]	validation_0-logloss:0.066061	validation_1-logloss:0.066941
# [174]	validation_0-logloss:0.066057	validation_1-logloss:0.066941
# [175]	validation_0-logloss:0.066054	validation_1-logloss:0.066942
# [176]	validation_0-logloss:0.06605	validation_1-logloss:0.066942
# [177]	validation_0-logloss:0.066044	validation_1-logloss:0.06694
# [178]	validation_0-logloss:0.066039	validation_1-logloss:0.066936
# [179]	validation_0-logloss:0.066034	validation_1-logloss:0.066935
# [180]	validation_0-logloss:0.06603	validation_1-logloss:0.066935
# [181]	validation_0-logloss:0.066026	validation_1-logloss:0.066934
# [182]	validation_0-logloss:0.066023	validation_1-logloss:0.066931
# [183]	validation_0-logloss:0.066018	validation_1-logloss:0.066932
# [184]	validation_0-logloss:0.066015	validation_1-logloss:0.066934
# [185]	validation_0-logloss:0.066011	validation_1-logloss:0.066934
# [186]	validation_0-logloss:0.066006	validation_1-logloss:0.06693
# [187]	validation_0-logloss:0.066002	validation_1-logloss:0.066929
# [188]	validation_0-logloss:0.065999	validation_1-logloss:0.066931
# [189]	validation_0-logloss:0.065996	validation_1-logloss:0.066928
# [190]	validation_0-logloss:0.065993	validation_1-logloss:0.066927
# [191]	validation_0-logloss:0.06599	validation_1-logloss:0.066928
# [192]	validation_0-logloss:0.065987	validation_1-logloss:0.066929
# [193]	validation_0-logloss:0.065983	validation_1-logloss:0.066926
# [194]	validation_0-logloss:0.065979	validation_1-logloss:0.06692
# [195]	validation_0-logloss:0.065974	validation_1-logloss:0.066915
# [196]	validation_0-logloss:0.065961	validation_1-logloss:0.066898
# [197]	validation_0-logloss:0.065957	validation_1-logloss:0.066893
# [198]	validation_0-logloss:0.065954	validation_1-logloss:0.066896
# [199]	validation_0-logloss:0.065951	validation_1-logloss:0.066893
# [200]	validation_0-logloss:0.065946	validation_1-logloss:0.066893
# [201]	validation_0-logloss:0.065941	validation_1-logloss:0.066893
# [202]	validation_0-logloss:0.065938	validation_1-logloss:0.06689
# [203]	validation_0-logloss:0.065933	validation_1-logloss:0.06689
# [204]	validation_0-logloss:0.06593	validation_1-logloss:0.066891
# [205]	validation_0-logloss:0.065926	validation_1-logloss:0.066892
# [206]	validation_0-logloss:0.065921	validation_1-logloss:0.066895
# [207]	validation_0-logloss:0.065914	validation_1-logloss:0.066887
# [208]	validation_0-logloss:0.065909	validation_1-logloss:0.066888
# [209]	validation_0-logloss:0.065901	validation_1-logloss:0.066884
# [210]	validation_0-logloss:0.065893	validation_1-logloss:0.066884
# [211]	validation_0-logloss:0.06589	validation_1-logloss:0.066882
# [212]	validation_0-logloss:0.065886	validation_1-logloss:0.066878
# [213]	validation_0-logloss:0.065882	validation_1-logloss:0.066877
# [214]	validation_0-logloss:0.065879	validation_1-logloss:0.066878
# [215]	validation_0-logloss:0.065877	validation_1-logloss:0.066877
# [216]	validation_0-logloss:0.065871	validation_1-logloss:0.066879
# [217]	validation_0-logloss:0.065866	validation_1-logloss:0.066879
# [218]	validation_0-logloss:0.065857	validation_1-logloss:0.066879
# [219]	validation_0-logloss:0.065852	validation_1-logloss:0.066874
# [220]	validation_0-logloss:0.065849	validation_1-logloss:0.066874
# [221]	validation_0-logloss:0.065845	validation_1-logloss:0.066873
# [222]	validation_0-logloss:0.065841	validation_1-logloss:0.066874
# [223]	validation_0-logloss:0.065835	validation_1-logloss:0.066867
# [224]	validation_0-logloss:0.065829	validation_1-logloss:0.06687
# [225]	validation_0-logloss:0.065825	validation_1-logloss:0.066867
# [226]	validation_0-logloss:0.065816	validation_1-logloss:0.066863
# [227]	validation_0-logloss:0.065813	validation_1-logloss:0.066861
# [228]	validation_0-logloss:0.065811	validation_1-logloss:0.066862
# [229]	validation_0-logloss:0.065807	validation_1-logloss:0.066862
# [230]	validation_0-logloss:0.0658	validation_1-logloss:0.066856
# [231]	validation_0-logloss:0.065796	validation_1-logloss:0.066858
# [232]	validation_0-logloss:0.065791	validation_1-logloss:0.066855
# [233]	validation_0-logloss:0.065789	validation_1-logloss:0.066855
# [234]	validation_0-logloss:0.065786	validation_1-logloss:0.066854
# [235]	validation_0-logloss:0.065783	validation_1-logloss:0.066857
# [236]	validation_0-logloss:0.06578	validation_1-logloss:0.066857
# [237]	validation_0-logloss:0.065776	validation_1-logloss:0.066857
# [238]	validation_0-logloss:0.065773	validation_1-logloss:0.066857
# [239]	validation_0-logloss:0.065767	validation_1-logloss:0.066857
# [240]	validation_0-logloss:0.065764	validation_1-logloss:0.066856
# [241]	validation_0-logloss:0.06576	validation_1-logloss:0.066855
# [242]	validation_0-logloss:0.065758	validation_1-logloss:0.066857
# [243]	validation_0-logloss:0.065753	validation_1-logloss:0.066852
# [244]	validation_0-logloss:0.065747	validation_1-logloss:0.066849
# [245]	validation_0-logloss:0.065744	validation_1-logloss:0.06685
# [246]	validation_0-logloss:0.065741	validation_1-logloss:0.066851
# [247]	validation_0-logloss:0.065738	validation_1-logloss:0.066851
# [248]	validation_0-logloss:0.065734	validation_1-logloss:0.066847
# [249]	validation_0-logloss:0.065725	validation_1-logloss:0.066839
# [250]	validation_0-logloss:0.065722	validation_1-logloss:0.066833
# [251]	validation_0-logloss:0.065693	validation_1-logloss:0.066807
# [252]	validation_0-logloss:0.065691	validation_1-logloss:0.066808
# [253]	validation_0-logloss:0.065688	validation_1-logloss:0.06681
# [254]	validation_0-logloss:0.065685	validation_1-logloss:0.06681
# [255]	validation_0-logloss:0.065682	validation_1-logloss:0.066809
# [256]	validation_0-logloss:0.065679	validation_1-logloss:0.066803
# [257]	validation_0-logloss:0.065676	validation_1-logloss:0.066804
# [258]	validation_0-logloss:0.065672	validation_1-logloss:0.066804
# [259]	validation_0-logloss:0.06567	validation_1-logloss:0.066805
# [260]	validation_0-logloss:0.065665	validation_1-logloss:0.066805
# [261]	validation_0-logloss:0.065663	validation_1-logloss:0.066807
# [262]	validation_0-logloss:0.065659	validation_1-logloss:0.066809
# [263]	validation_0-logloss:0.065658	validation_1-logloss:0.066811
# [264]	validation_0-logloss:0.065654	validation_1-logloss:0.066813
# [265]	validation_0-logloss:0.065651	validation_1-logloss:0.066811
# [266]	validation_0-logloss:0.065649	validation_1-logloss:0.066811
# Stopping. Best iteration:
# [256]	validation_0-logloss:0.065679	validation_1-logloss:0.066803
# 100%|██████████| 24/24 [2:55:41<00:00, 439.25s/it]

# %% [markdown]
# ## 提交结果

# %%
# 提交结果：选取（加权？）概率最大(top7?)的新产品
pre_month_col=['1_'+x for x in target_raw_cols] # 上个月的产品购买记录列
pre_month_product=X_TRAIN[["ncodpers"]+pre_month_col]
result=pd.merge(result, pre_month_product, on=['ncodpers'], how='left') #当月产品购买概率预测+上个月产品购买记录

def func(x): #0->1;1->0
  if int(x)==0:
    return 1
  else:
    return 0

def drop_old_product(result,target_raw_cols): # 将上个月购买过的产品购买概率记为0
  for col in target_raw_cols:
    result['1_'+col]=result[col].apply(func) 
    result[col]=result[col]*result['1_'+col]
  return result

result=drop_old_product(result,target_raw_cols)

added_products_array=np.array(result[target_raw_cols])

target_raw_array = np.array(target_raw_cols)    # list->array
added_products_array = np.argsort(added_products_array, axis = 1) # 每一行排序（从小到大）
added_products_array = np.fliplr(added_products_array)[:, :7] # 反转排序结果，选取top7
added_products = [" ".join(list(target_raw_array[prod])) for prod in added_products_array] # 以空格连接这7项产品

result["added_products"]=added_products
result=result.drop(target_raw_cols+pre_month_col, axis=1) # 丢弃上个月的购买历史记录及当月购买产品概率预测

print(result.head())
print(result.tail())
# 保存提交结果
result.to_csv('./result.csv', index=False)
# Out:
#    ncodpers                                     added_products
# 0     15889  ind_cco_fin_ult1 ind_ctpp_fin_ult1 ind_valo_fi...
# 1   1170544  ind_cco_fin_ult1 ind_recibo_ult1 ind_reca_fin_...
# 2   1170545  ind_cco_fin_ult1 ind_recibo_ult1 ind_nomina_ul...
# 3   1170547  ind_cco_fin_ult1 ind_nom_pens_ult1 ind_nomina_...
# 4   1170548  ind_cco_fin_ult1 ind_nom_pens_ult1 ind_nomina_...
#         ncodpers                                     added_products
# 929610    660237  ind_ecue_fin_ult1 ind_cno_fin_ult1 ind_recibo_...
# 929611    660238  ind_cco_fin_ult1 ind_pres_fin_ult1 ind_reca_fi...
# 929612    660240  ind_cco_fin_ult1 ind_ctop_fin_ult1 ind_deme_fi...
# 929613    660243  ind_cco_fin_ult1 ind_reca_fin_ult1 ind_viv_fin...
# 929614    660248  ind_ctop_fin_ult1 ind_cco_fin_ult1 ind_pres_fi...
